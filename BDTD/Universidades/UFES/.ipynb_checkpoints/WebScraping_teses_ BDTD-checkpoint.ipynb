# %% [markdown]
# Script para buscar resumos das teses elaboradas pelos empregados da Petrobras

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import json
import nltk
from nltk.tokenize import word_tokenize
from langdetect import detect
from langdetect import detect_langs
from keras.models import load_model
import gensim
from gensim.models import Word2Vec
import csv
import re
# Out:
# Using TensorFlow backend.
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# Definindo configurações globais de proxy para realizar a extração dentro da rede Petrobras
chave = 'upe2'
pwd = 'fBO61291'
proxy_url = 'http://'+chave+':'+pwd+'@inet-sys.gnet.petrobras.com.br:804/'
proxies = {
  'http' : proxy_url ,
  'https' : proxy_url ,
}

# %% [markdown]
# Inicialmente entraremos no site da BDTD e buscaremos os links de todas as teses de uma determinada intituição.

# %%
#função para coletar os links das tese

def get_links(page):
        
    #preparar a url
    url = ('http://bdtd.ibict.br/vufind/Search/Results?filter%5B%5D=institution%3A%22UFES%22&type=AllFields&page=' +
           str(page))
    
    #Fazer requisição e parsear o arquivo html
    f = requests.get(url, proxies = proxies).text 
    soup = bs(f, "html.parser")

    #Coletando link para as teses
    links = []
    for doc in soup.find_all('a', href=True):
        if 'title' in doc.get('class', []):
            links.append(doc['href'])
    return links

# %%
#Coletar o link de todas as teses
start_page = 1
n_pages = 485 # Cada página retorna 20 teses

links = []

for p in range(start_page, n_pages):
    link = get_links(p)
    if link != []:
        links = links + link
    else:
        break
    
    if p % 100 == 0:
        print (p*20, ' links capturados, ', p, ' páginas')
        with open('links_ufes', "w") as output:
            writer = csv.writer(output, lineterminator='\n')
            for val in links:
                writer.writerow([val])
                
with open('links_ufes', "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in links:
        writer.writerow([val]) 
print (p*20, ' links capturados, ', p, ' páginas')
# Out:
# 2000  links capturados,  100  páginas
# 4000  links capturados,  200  páginas
# 6000  links capturados,  300  páginas
# 8000  links capturados,  400  páginas
# 9680  links capturados,  484  páginas

# %%
# Abrindo arquivo gravado anteriormente

#links = []
#with open('links_ufes', 'r') as f:
#    reader = csv.reader(f)
#    for link in reader:
#        links.append(link[0])

# %% [markdown]
# Em seguida vamos recuperar os metadados de cada link coletado anteriormente.

# %%
#função para buscar os metadados das teses no BDTD
def tese_link(link):
    #definir url
    url = 'http://bdtd.ibict.br' + link
    
    #Requisitar html e fazer o parser
    f = requests.get(url, proxies = proxies).text 
    soup = bs(f, "html.parser")

    #Dicionário para armazenar as informações da tese
    tese = {}  
    
    #Adicionar título
    tese['Title'] = soup.find('h3').get_text()
    for doc in soup.find_all('tr'):
        #Identificar atributo
        try:
            atributo = doc.find('th').get_text()
        except:
            pass
        #Verificar se o atributo possui mais de um dado
        for row in doc.find_all('td'):
            #Adicionar o atributo no dicionário
            if row.find('div') == None:
                try:
                    tese[atributo] = doc.find('td').get_text()
                except:
                    pass
            else:
                element = []
                #No dicionário, adicionar todos os dados ao seu respectivo atributo
                for e in doc.find_all('div'):
                    try:
                        sub_e = []
                        for sub_element in e.find_all('a'):
                            element.append(sub_element.get_text()) 
                        #element.append(sub_e)
                    except:
                        pass
                tese[atributo] = element
    
    return(tese)

# %% [markdown]
# Como em alguns casos o resumo português e inglês se misturaram, foi implementado uma função para separar os textos misturados

# %%
# Função para separar resumos português e inglês
def separacao_port_engl(abstract):

    mix_sent = nltk.sent_tokenize(abstract)

    new_mix = []
    for sent in mix_sent:
        position = sent.find('.')
        if position != len(sent)-1:
            sent_1 = sent[:position+1]
            sent_2 = sent[position+1:]
            new_mix.append(sent_1)
            new_mix.append(sent_2)
        else:
            new_mix.append(sent)

    mix_sent = new_mix

    port = []
    engl = []

    for sent in mix_sent:
        try:
            if detect (sent) == 'pt':
                port.append(sent)
            else:
                engl.append (sent)
        except:
            pass

    port = " ".join(port)
    engl = " ".join(engl)

    return(port, engl)

# %% [markdown]
# Até esse momento estamos recuperando as informações de todas as teses de uma determinada instituição. No entanto o objetivo é gravar os metadados e salvar o arquivo apenas das teses relacionadas a O&G. Portanto, vamos carregar os algoritmos de classificação e de vetorização de palavras treinados previamente.

# %%
# Carregando modelo Word2Vec
BDTD_word2vec_50 = Word2Vec.load("..\..\..\Embeddings\BDTD_word2vec_50")
# Carregando modelo keras
model_keras = load_model('..\..\..\model_cnn.h5')
model_keras.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:131: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 400, 50)           9289150
# _________________________________________________________________
# spatial_dropout1d_6 (Spatial (None, 400, 50)           0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 396, 128)          32128
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 198, 128)          0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 198, 128)          0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 194, 128)          82048
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 97, 128)           0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 97, 128)           0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 93, 128)           82048
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 128)               0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               66048
# _________________________________________________________________
# dense_31 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 9,814,591
# Trainable params: 525,441
# Non-trainable params: 9,289,150
# _________________________________________________________________

# %%
# dicionário proveniente do modelo de word embedding para converter palavras em índices
word2index = {}
for index, word in enumerate(BDTD_word2vec_50.wv.index2word):
    word2index[word] = index
    
# Função para converter texto em sequência de índices
def index_pad_text(text, maxlen, word2index):
    maxlen = 400
    new_text = [] 
    
    for word in word_tokenize(text):
        try:
            new_text.append(word2index[word])
        except:
            pass
    # Add the padding for each sentence. Here I am padding with 0
    if len(new_text) > maxlen:
        new_text = new_text[:400]
    else:
        new_text += [0] * (maxlen - len(new_text))

    return np.array(new_text)

maxlen = 400

# %% [markdown]
# Para cada link coletado será fita as seguintes tarefas:
# * verificar se o texto português e inglês estão misturados;
# * transformar o texto em sequência de índices;
# * classificar quanto a relevância ao domínio de O&G;
# * se for relevante, gravar os metadados

# %%
# Dicionário para agrupar os metadados
metadados = {}
# Contadores te links testados e classificados como O&G
n_test = 0
n_pet = 0
# Testando cada link de links
for link in links:
    n_test += 1
    try:
        # Recuperar o metadados de uma tese
        metadado = tese_link(link)
        # Verificar se existe resumo em inglês, separar texto português/inglês e realocar 
        # os textos separados nas respectivas colunas
        if 'Resumo inglês:' not in metadado:
            metadado['Resumo inglês:'] = separacao_port_engl(metadado['Resumo Português:'])[1]
        metadado['Resumo Português:'] = separacao_port_engl(metadado['Resumo Português:'])[0]
        # Colocando o texto em minúscula
        text = metadado['Resumo Português:'].lower()
        # Convertendo as palavras em sequencias de acordo com o modelo word2vec
        text_seq = index_pad_text(text, maxlen, word2index)
        text_seq = text_seq.reshape((1, 400))
        # Usando o algoritmo classificador para prever se a tese é relevante
        pred = model_keras.predict(text_seq)[0]
        #Se a classificação for menor do que 0.2 manter os metadados
        if (pred < 0.2 and len(text) > 100):
            metadado['Classificador'] = pred[0]
            texto_completo = metadado['Download Texto Completo:']
            metadados[texto_completo] = metadado
            n_pet += 1
            # Gravando os resultados em JSON
            metadados_ufes = pd.DataFrame.from_dict(metadados, orient='index')
            metadados_ufes.to_json('metadados_ufes.json', orient = 'index')
            print(n_test, " teses avaliadas e ", n_pet, " teses relacionadas a O&G encontradas.")
    
    except:
        pass
# Out:
# 19  teses avaliadas e  1  teses relacionadas a O&G encontradas.
# 172  teses avaliadas e  2  teses relacionadas a O&G encontradas.
# 181  teses avaliadas e  3  teses relacionadas a O&G encontradas.
# 188  teses avaliadas e  4  teses relacionadas a O&G encontradas.
# 191  teses avaliadas e  5  teses relacionadas a O&G encontradas.
# 209  teses avaliadas e  6  teses relacionadas a O&G encontradas.
# 250  teses avaliadas e  7  teses relacionadas a O&G encontradas.
# 252  teses avaliadas e  8  teses relacionadas a O&G encontradas.
# 350  teses avaliadas e  9  teses relacionadas a O&G encontradas.
# 433  teses avaliadas e  10  teses relacionadas a O&G encontradas.
# 461  teses avaliadas e  11  teses relacionadas a O&G encontradas.
# 463  teses avaliadas e  12  teses relacionadas a O&G encontradas.
# 469  teses avaliadas e  13  teses relacionadas a O&G encontradas.
# 484  teses avaliadas e  14  teses relacionadas a O&G encontradas.
# 494  teses avaliadas e  15  teses relacionadas a O&G encontradas.
# 495  teses avaliadas e  16  teses relacionadas a O&G encontradas.
# 498  teses avaliadas e  17  teses relacionadas a O&G encontradas.
# 500  teses avaliadas e  18  teses relacionadas a O&G encontradas.
# 506  teses avaliadas e  19  teses relacionadas a O&G encontradas.
# 513  teses avaliadas e  20  teses relacionadas a O&G encontradas.
# 514  teses avaliadas e  21  teses relacionadas a O&G encontradas.
# 519  teses avaliadas e  22  teses relacionadas a O&G encontradas.
# 522  teses avaliadas e  23  teses relacionadas a O&G encontradas.
# 525  teses avaliadas e  24  teses relacionadas a O&G encontradas.
# 530  teses avaliadas e  25  teses relacionadas a O&G encontradas.
# 532  teses avaliadas e  26  teses relacionadas a O&G encontradas.
# 537  teses avaliadas e  27  teses relacionadas a O&G encontradas.
# 539  teses avaliadas e  28  teses relacionadas a O&G encontradas.
# 540  teses avaliadas e  29  teses relacionadas a O&G encontradas.
# 543  teses avaliadas e  30  teses relacionadas a O&G encontradas.
# 545  teses avaliadas e  31  teses relacionadas a O&G encontradas.
# 546  teses avaliadas e  32  teses relacionadas a O&G encontradas.
# 547  teses avaliadas e  33  teses relacionadas a O&G encontradas.
# 548  teses avaliadas e  34  teses relacionadas a O&G encontradas.
# 553  teses avaliadas e  35  teses relacionadas a O&G encontradas.
# 557  teses avaliadas e  36  teses relacionadas a O&G encontradas.
# 575  teses avaliadas e  37  teses relacionadas a O&G encontradas.
# 576  teses avaliadas e  38  teses relacionadas a O&G encontradas.
# 1149  teses avaliadas e  39  teses relacionadas a O&G encontradas.
# 1150  teses avaliadas e  40  teses relacionadas a O&G encontradas.
# 1154  teses avaliadas e  41  teses relacionadas a O&G encontradas.
# 1155  teses avaliadas e  42  teses relacionadas a O&G encontradas.
# 1157  teses avaliadas e  43  teses relacionadas a O&G encontradas.
# 1158  teses avaliadas e  44  teses relacionadas a O&G encontradas.
# 1161  teses avaliadas e  45  teses relacionadas a O&G encontradas.
# 1382  teses avaliadas e  46  teses relacionadas a O&G encontradas.
# 1535  teses avaliadas e  47  teses relacionadas a O&G encontradas.
# 2101  teses avaliadas e  48  teses relacionadas a O&G encontradas.
# 2115  teses avaliadas e  49  teses relacionadas a O&G encontradas.
# 2116  teses avaliadas e  50  teses relacionadas a O&G encontradas.
# 2126  teses avaliadas e  51  teses relacionadas a O&G encontradas.
# 2134  teses avaliadas e  52  teses relacionadas a O&G encontradas.
# 2148  teses avaliadas e  53  teses relacionadas a O&G encontradas.
# 2167  teses avaliadas e  54  teses relacionadas a O&G encontradas.
# 2184  teses avaliadas e  55  teses relacionadas a O&G encontradas.
# 2205  teses avaliadas e  56  teses relacionadas a O&G encontradas.
# 2233  teses avaliadas e  57  teses relacionadas a O&G encontradas.
# 2305  teses avaliadas e  58  teses relacionadas a O&G encontradas.
# 2348  teses avaliadas e  59  teses relacionadas a O&G encontradas.
# 2355  teses avaliadas e  60  teses relacionadas a O&G encontradas.
# 2358  teses avaliadas e  61  teses relacionadas a O&G encontradas.
# 2371  teses avaliadas e  62  teses relacionadas a O&G encontradas.
# 2380  teses avaliadas e  63  teses relacionadas a O&G encontradas.
# 2381  teses avaliadas e  64  teses relacionadas a O&G encontradas.
# 2390  teses avaliadas e  65  teses relacionadas a O&G encontradas.
# 2391  teses avaliadas e  66  teses relacionadas a O&G encontradas.
# 2399  teses avaliadas e  67  teses relacionadas a O&G encontradas.
# 2406  teses avaliadas e  68  teses relacionadas a O&G encontradas.
# 2407  teses avaliadas e  69  teses relacionadas a O&G encontradas.
# 2408  teses avaliadas e  70  teses relacionadas a O&G encontradas.
# 2418  teses avaliadas e  71  teses relacionadas a O&G encontradas.
# 2421  teses avaliadas e  72  teses relacionadas a O&G encontradas.
# 2422  teses avaliadas e  73  teses relacionadas a O&G encontradas.
# 2455  teses avaliadas e  74  teses relacionadas a O&G encontradas.
# 2465  teses avaliadas e  75  teses relacionadas a O&G encontradas.
# 2564  teses avaliadas e  76  teses relacionadas a O&G encontradas.
# 2577  teses avaliadas e  77  teses relacionadas a O&G encontradas.
# 2613  teses avaliadas e  78  teses relacionadas a O&G encontradas.
# 2615  teses avaliadas e  79  teses relacionadas a O&G encontradas.
# 2764  teses avaliadas e  80  teses relacionadas a O&G encontradas.
# 2766  teses avaliadas e  81  teses relacionadas a O&G encontradas.
# 2769  teses avaliadas e  82  teses relacionadas a O&G encontradas.
# 2837  teses avaliadas e  83  teses relacionadas a O&G encontradas.
# 2929  teses avaliadas e  84  teses relacionadas a O&G encontradas.
# 3179  teses avaliadas e  85  teses relacionadas a O&G encontradas.
# 3506  teses avaliadas e  86  teses relacionadas a O&G encontradas.
# 3771  teses avaliadas e  87  teses relacionadas a O&G encontradas.
# 3779  teses avaliadas e  88  teses relacionadas a O&G encontradas.
# 3781  teses avaliadas e  89  teses relacionadas a O&G encontradas.
# 3784  teses avaliadas e  90  teses relacionadas a O&G encontradas.
# 3818  teses avaliadas e  91  teses relacionadas a O&G encontradas.
# 3849  teses avaliadas e  92  teses relacionadas a O&G encontradas.
# 3921  teses avaliadas e  93  teses relacionadas a O&G encontradas.
# 3930  teses avaliadas e  94  teses relacionadas a O&G encontradas.
# 3933  teses avaliadas e  95  teses relacionadas a O&G encontradas.
# 3937  teses avaliadas e  96  teses relacionadas a O&G encontradas.
# 3939  teses avaliadas e  97  teses relacionadas a O&G encontradas.
# 3942  teses avaliadas e  98  teses relacionadas a O&G encontradas.
# 3953  teses avaliadas e  99  teses relacionadas a O&G encontradas.
# 4252  teses avaliadas e  100  teses relacionadas a O&G encontradas.
# 4258  teses avaliadas e  101  teses relacionadas a O&G encontradas.
# 4291  teses avaliadas e  102  teses relacionadas a O&G encontradas.
# 4295  teses avaliadas e  103  teses relacionadas a O&G encontradas.
# 4646  teses avaliadas e  104  teses relacionadas a O&G encontradas.
# 4648  teses avaliadas e  105  teses relacionadas a O&G encontradas.
# 4651  teses avaliadas e  106  teses relacionadas a O&G encontradas.
# 4654  teses avaliadas e  107  teses relacionadas a O&G encontradas.
# 4655  teses avaliadas e  108  teses relacionadas a O&G encontradas.
# 4665  teses avaliadas e  109  teses relacionadas a O&G encontradas.
# 4667  teses avaliadas e  110  teses relacionadas a O&G encontradas.
# 4668  teses avaliadas e  111  teses relacionadas a O&G encontradas.
# 4675  teses avaliadas e  112  teses relacionadas a O&G encontradas.
# 4687  teses avaliadas e  113  teses relacionadas a O&G encontradas.
# 4736  teses avaliadas e  114  teses relacionadas a O&G encontradas.
# 4740  teses avaliadas e  115  teses relacionadas a O&G encontradas.
# 4796  teses avaliadas e  116  teses relacionadas a O&G encontradas.
# 4966  teses avaliadas e  117  teses relacionadas a O&G encontradas.
# 5146  teses avaliadas e  118  teses relacionadas a O&G encontradas.
# 5156  teses avaliadas e  119  teses relacionadas a O&G encontradas.
# 5157  teses avaliadas e  120  teses relacionadas a O&G encontradas.
# 5159  teses avaliadas e  121  teses relacionadas a O&G encontradas.
# 5161  teses avaliadas e  122  teses relacionadas a O&G encontradas.
# 5456  teses avaliadas e  123  teses relacionadas a O&G encontradas.
# 5571  teses avaliadas e  124  teses relacionadas a O&G encontradas.
# 5634  teses avaliadas e  125  teses relacionadas a O&G encontradas.
# 5646  teses avaliadas e  126  teses relacionadas a O&G encontradas.
# 5697  teses avaliadas e  127  teses relacionadas a O&G encontradas.
# 5699  teses avaliadas e  128  teses relacionadas a O&G encontradas.
# 5780  teses avaliadas e  129  teses relacionadas a O&G encontradas.
# 5794  teses avaliadas e  130  teses relacionadas a O&G encontradas.
# 5813  teses avaliadas e  131  teses relacionadas a O&G encontradas.
# 5836  teses avaliadas e  132  teses relacionadas a O&G encontradas.
# 5860  teses avaliadas e  133  teses relacionadas a O&G encontradas.
# 5863  teses avaliadas e  134  teses relacionadas a O&G encontradas.
# 5864  teses avaliadas e  135  teses relacionadas a O&G encontradas.
# 5866  teses avaliadas e  136  teses relacionadas a O&G encontradas.
# 5868  teses avaliadas e  137  teses relacionadas a O&G encontradas.
# 5870  teses avaliadas e  138  teses relacionadas a O&G encontradas.
# 5872  teses avaliadas e  139  teses relacionadas a O&G encontradas.
# 5875  teses avaliadas e  140  teses relacionadas a O&G encontradas.
# 5979  teses avaliadas e  141  teses relacionadas a O&G encontradas.
# 6026  teses avaliadas e  142  teses relacionadas a O&G encontradas.
# 6063  teses avaliadas e  143  teses relacionadas a O&G encontradas.
# 6095  teses avaliadas e  144  teses relacionadas a O&G encontradas.
# 6837  teses avaliadas e  145  teses relacionadas a O&G encontradas.
# 6839  teses avaliadas e  146  teses relacionadas a O&G encontradas.
# 6840  teses avaliadas e  147  teses relacionadas a O&G encontradas.
# 6855  teses avaliadas e  148  teses relacionadas a O&G encontradas.
# 6857  teses avaliadas e  149  teses relacionadas a O&G encontradas.
# 6861  teses avaliadas e  150  teses relacionadas a O&G encontradas.
# 6886  teses avaliadas e  151  teses relacionadas a O&G encontradas.
# 6894  teses avaliadas e  152  teses relacionadas a O&G encontradas.
# 6933  teses avaliadas e  153  teses relacionadas a O&G encontradas.
# 6934  teses avaliadas e  154  teses relacionadas a O&G encontradas.
# 6944  teses avaliadas e  155  teses relacionadas a O&G encontradas.
# 6948  teses avaliadas e  156  teses relacionadas a O&G encontradas.
# 6949  teses avaliadas e  157  teses relacionadas a O&G encontradas.
# 6953  teses avaliadas e  158  teses relacionadas a O&G encontradas.
# 6955  teses avaliadas e  159  teses relacionadas a O&G encontradas.
# 6961  teses avaliadas e  160  teses relacionadas a O&G encontradas.
# 6964  teses avaliadas e  161  teses relacionadas a O&G encontradas.
# 6966  teses avaliadas e  162  teses relacionadas a O&G encontradas.
# 6970  teses avaliadas e  163  teses relacionadas a O&G encontradas.
# 6972  teses avaliadas e  164  teses relacionadas a O&G encontradas.
# 6974  teses avaliadas e  165  teses relacionadas a O&G encontradas.
# 6978  teses avaliadas e  166  teses relacionadas a O&G encontradas.
# 7626  teses avaliadas e  167  teses relacionadas a O&G encontradas.
# 7674  teses avaliadas e  168  teses relacionadas a O&G encontradas.
# 7833  teses avaliadas e  169  teses relacionadas a O&G encontradas.
# 7852  teses avaliadas e  170  teses relacionadas a O&G encontradas.
# 8021  teses avaliadas e  171  teses relacionadas a O&G encontradas.
# 8022  teses avaliadas e  172  teses relacionadas a O&G encontradas.
# 8025  teses avaliadas e  173  teses relacionadas a O&G encontradas.
# 8297  teses avaliadas e  174  teses relacionadas a O&G encontradas.
# 8667  teses avaliadas e  175  teses relacionadas a O&G encontradas.
# 8668  teses avaliadas e  176  teses relacionadas a O&G encontradas.
# 8671  teses avaliadas e  177  teses relacionadas a O&G encontradas.
# 8705  teses avaliadas e  178  teses relacionadas a O&G encontradas.
# 8711  teses avaliadas e  179  teses relacionadas a O&G encontradas.
# 8722  teses avaliadas e  180  teses relacionadas a O&G encontradas.
# 8725  teses avaliadas e  181  teses relacionadas a O&G encontradas.
# 8737  teses avaliadas e  182  teses relacionadas a O&G encontradas.
# 8747  teses avaliadas e  183  teses relacionadas a O&G encontradas.
# 8839  teses avaliadas e  184  teses relacionadas a O&G encontradas.
# 8861  teses avaliadas e  185  teses relacionadas a O&G encontradas.
# 8864  teses avaliadas e  186  teses relacionadas a O&G encontradas.
# 8880  teses avaliadas e  187  teses relacionadas a O&G encontradas.
# 8885  teses avaliadas e  188  teses relacionadas a O&G encontradas.
# 8897  teses avaliadas e  189  teses relacionadas a O&G encontradas.
# 8936  teses avaliadas e  190  teses relacionadas a O&G encontradas.
# 8939  teses avaliadas e  191  teses relacionadas a O&G encontradas.
# 8950  teses avaliadas e  192  teses relacionadas a O&G encontradas.
# 8951  teses avaliadas e  193  teses relacionadas a O&G encontradas.
# 8952  teses avaliadas e  194  teses relacionadas a O&G encontradas.
# 8956  teses avaliadas e  195  teses relacionadas a O&G encontradas.
# 8957  teses avaliadas e  196  teses relacionadas a O&G encontradas.
# 8959  teses avaliadas e  197  teses relacionadas a O&G encontradas.
# 8968  teses avaliadas e  198  teses relacionadas a O&G encontradas.
# 8981  teses avaliadas e  199  teses relacionadas a O&G encontradas.
# 8982  teses avaliadas e  200  teses relacionadas a O&G encontradas.
# 8983  teses avaliadas e  201  teses relacionadas a O&G encontradas.
# 8993  teses avaliadas e  202  teses relacionadas a O&G encontradas.
# 8995  teses avaliadas e  203  teses relacionadas a O&G encontradas.
# 8998  teses avaliadas e  204  teses relacionadas a O&G encontradas.
# 9003  teses avaliadas e  205  teses relacionadas a O&G encontradas.
# 9021  teses avaliadas e  206  teses relacionadas a O&G encontradas.
# 9022  teses avaliadas e  207  teses relacionadas a O&G encontradas.
# 9515  teses avaliadas e  208  teses relacionadas a O&G encontradas.
# 9553  teses avaliadas e  209  teses relacionadas a O&G encontradas.

# %%
# Incluindo um ID para cada tese
universidade = 'UFES'
metadados_ufes['PDF_ID'] = metadados_ufes['Download Texto Completo:'].apply(lambda x: universidade + 
                                                                            '_' + 
                                                                            re.sub('/', '_', x[-7:]))

# %%
metadados_ufes.to_json('metadados_ufes.json', orient = 'index')

# %%
# Carregando arquivos já gravados
metadados_ufes = pd.read_json('metadados_ufes.json', orient = 'index')

# %% [markdown]
# A próxima etapa será fazer o download das teses classificadas como relevante para o domínio de O&G

# %%
for tese in metadados_ufes.iterrows():
    print(tese[1]['PDF_ID'])
    try:
        #preparar a url
        url = tese[1]['Download Texto Completo:']

        #Fazer requisição e parsear o arquivo html
        f = requests.get(url, proxies = proxies).text 
        soup = bs(f, "html.parser")

        #Coletando link para arquivo das teses
        links = []
        for doc in soup.find_all('a', href=True):
            if doc.get_text() == 'View/Open':
                links.append(doc['href'])

        #Recuperando e gravando arquivo PDF
        url = 'http://repositorio.ufes.br' + links[0]
        pdf = requests.get(url, proxies = proxies)
        filename = tese[1]['PDF_ID'] + '.pdf'
        with open(filename, 'wb') as f:
            f.write(pdf.content)
    except:
        pass
# Out:
# UFES_0_10217
# UFES_0_10219
# UFES_0_10220
# UFES_0_10235
# UFES_0_10237
# UFES_0_10241
# UFES_0_10266
# UFES_0_10274
# UFES_0_10316
# UFES_0_10431
# UFES_0_10541
# UFES_0_10553
# UFES_0_10604
# UFES_0_10606
# UFES_0_10687
# UFES_0_10701
# UFES_0_10720
# UFES_0_10744
# UFES_0_10772
# UFES_0_10775
# UFES_0_10776
# UFES_0_10778
# UFES_0_10780
# UFES_0_10782
# UFES_0_10784
# UFES_0_10787
# UFES_0_10892
# UFES_10_1092
# UFES_0_10939
# UFES_0_10977
# UFES_0_11010
# UFES_0_11293
# UFES_0_11342
# UFES_10_1261
# UFES_10_1269
# UFES_10_1281
# UFES_10_1286
# UFES_10_1309
# UFES_10_1348
# UFES_10_1353
# UFES_10_1488
# UFES_10_1606
# UFES_10_1607
# UFES_10_1609
# UFES_10_1688
# UFES_10_1720
# UFES_10_1721
# UFES_10_1865
# UFES_10_2045
# UFES_10_2058
# UFES_10_2475
# UFES_10_2635
# UFES_10_2806
# UFES_10_3566
# UFES_10_3879
# UFES_10_3893
# UFES_10_3894
# UFES_10_3904
# UFES_10_3912
# UFES_10_3927
# UFES_10_3946
# UFES_10_3963
# UFES_10_3984
# UFES_10_4012
# UFES_10_4084
# UFES_10_4127
# UFES_10_4134
# UFES_10_4137
# UFES_10_4150
# UFES_10_4159
# UFES_10_4160
# UFES_10_4169
# UFES_10_4170
# UFES_10_4178
# UFES_10_4185
# UFES_10_4186
# UFES_10_4187
# UFES_10_4197
# UFES_10_4200
# UFES_10_4201
# UFES_10_4234
# UFES_10_4244
# UFES_10_4343
# UFES_10_4356
# UFES_10_4392
# UFES_10_4394
# UFES_10_4640
# UFES_10_4642
# UFES_10_4648
# UFES_10_4663
# UFES_10_4673
# UFES_10_4674
# UFES_10_4677
# UFES_10_4679
# UFES_10_4685
# UFES_10_4692
# UFES_10_4693
# UFES_10_4698
# UFES_10_4701
# UFES_10_4704
# UFES_10_4709
# UFES_10_4711
# UFES_10_4716
# UFES_10_4718
# UFES_10_4719
# UFES_10_4722
# UFES_10_4724
# UFES_10_4725
# UFES_10_4726
# UFES_10_4727
# UFES_10_4732
# UFES_10_4736
# UFES_10_4754
# UFES_10_4755
# UFES_10_5337
# UFES_10_5338
# UFES_10_5342
# UFES_10_5343
# UFES_10_5345
# UFES_10_5346
# UFES_10_5349
# UFES_10_6152
# UFES_10_6228
# UFES_10_6238
# UFES_10_6242
# UFES_10_6246
# UFES_10_6248
# UFES_10_6251
# UFES_10_6262
# UFES_10_6305
# UFES_10_6345
# UFES_10_6739
# UFES_10_6748
# UFES_10_6752
# UFES_10_6755
# UFES_10_6786
# UFES_10_6918
# UFES_10_6924
# UFES_10_6957
# UFES_10_6961
# UFES_10_7318
# UFES_10_7320
# UFES_10_7323
# UFES_10_7326
# UFES_10_7327
# UFES_10_7337
# UFES_10_7339
# UFES_10_7340
# UFES_10_7347
# UFES_10_7359
# UFES_10_7408
# UFES_10_7412
# UFES_10_7468
# UFES_10_7638
# UFES_10_7818
# UFES_10_7828
# UFES_10_7829
# UFES_10_7831
# UFES_10_7833
# UFES_10_8426
# UFES_10_8427
# UFES_10_8437
# UFES_10_8441
# UFES_10_8442
# UFES_10_8446
# UFES_10_8448
# UFES_10_8454
# UFES_10_8457
# UFES_10_8459
# UFES_10_8463
# UFES_10_8465
# UFES_10_8467
# UFES_10_8471
# UFES_10_8800
# UFES_10_9115
# UFES_10_9153
# UFES_10_9458
# UFES_10_9459
# UFES_10_9462
# UFES_10_9496
# UFES_10_9502
# UFES_10_9513
# UFES_10_9516
# UFES_10_9528
# UFES_10_9538
# UFES_10_9630
# UFES_10_9652
# UFES_10_9655
# UFES_10_9671
# UFES_10_9676
# UFES_10_9688
# UFES_10_9727
# UFES_10_9730
# UFES_10_9741
# UFES_10_9742
# UFES_10_9743
# UFES_10_9747
# UFES_10_9748
# UFES_10_9750
# UFES_10_9759
# UFES_10_9772
# UFES_10_9773
# UFES_10_9774
# UFES_10_9784
# UFES_10_9786
# UFES_10_9789
# UFES_10_9794
# UFES_10_9812
# UFES_10_9813
