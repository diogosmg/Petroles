# %% [markdown]
# Script para buscar resumos das teses elaboradas pelos empregados da Petrobras

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import json
import nltk
from nltk.tokenize import word_tokenize
from langdetect import detect
from langdetect import detect_langs
from keras.models import load_model
import gensim
from gensim.models import Word2Vec
import csv
import re

# %%
# Definindo configurações globais de proxy para realizar a extração dentro da rede Petrobras
chave = 'upe2'
pwd = 'fBO61291'
proxy_url = 'http://'+chave+':'+pwd+'@inet-sys.gnet.petrobras.com.br:804/'
proxies = {
  'http' : proxy_url ,
  'https' : proxy_url ,
}

# %% [markdown]
# Inicialmente entraremos no site da BDTD e buscaremos os links de todas as teses de uma determinada intituição.

# %%
#função para coletar os links das tese

def get_links(page):
        
    #preparar a url
    url = ('http://bdtd.ibict.br/vufind/Search/Results?filter%5B%5D=institution%3A%22UFES%22&type=AllFields&page=' +
           str(page))
    
    #Fazer requisição e parsear o arquivo html
    f = requests.get(url, proxies = proxies).text 
    soup = bs(f, "html.parser")

    #Coletando link para as teses
    links = []
    for doc in soup.find_all('a', href=True):
        if 'title' in doc.get('class', []):
            links.append(doc['href'])
    return links

# %%
#Coletar o link de todas as teses
start_page = 601
n_pages = 1030 # Cada página retorna 20 teses

links = []

for p in range(start_page, n_pages):
    link = get_links(p)
    if link != []:
        links = links + link
    else:
        break
    
    if p % 100 == 0:
        print (p*20, ' links capturados, ', p, ' páginas')
        with open('links_ufes', "w") as output:
            writer = csv.writer(output, lineterminator='\n')
            for val in links:
                writer.writerow([val])
                
with open('links_ufes', "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in links:
        writer.writerow([val]) 
print (p*20, ' links capturados, ', p, ' páginas')
# Out:
# 14000  links capturados,  700  páginas
# 16000  links capturados,  800  páginas
# 18000  links capturados,  900  páginas
# 20000  links capturados,  1000  páginas
# 20580  links capturados,  1029  páginas

# %%
# Abrindo arquivo gravado anteriormente

#links = []
#with open('links_ufes', 'r') as f:
#    reader = csv.reader(f)
#    for link in reader:
#        links.append(link[0])

# %% [markdown]
# Em seguida vamos recuperar os metadados de cada link coletado anteriormente.

# %%
#função para buscar os metadados das teses no BDTD
def tese_link(link):
    #definir url
    url = 'http://bdtd.ibict.br' + link
    
    #Requisitar html e fazer o parser
    f = requests.get(url, proxies = proxies).text 
    soup = bs(f, "html.parser")

    #Dicionário para armazenar as informações da tese
    tese = {}  
    
    #Adicionar título
    tese['Title'] = soup.find('h3').get_text()
    for doc in soup.find_all('tr'):
        #Identificar atributo
        try:
            atributo = doc.find('th').get_text()
        except:
            pass
        #Verificar se o atributo possui mais de um dado
        for row in doc.find_all('td'):
            #Adicionar o atributo no dicionário
            if row.find('div') == None:
                try:
                    tese[atributo] = doc.find('td').get_text()
                except:
                    pass
            else:
                element = []
                #No dicionário, adicionar todos os dados ao seu respectivo atributo
                for e in doc.find_all('div'):
                    try:
                        sub_e = []
                        for sub_element in e.find_all('a'):
                            element.append(sub_element.get_text()) 
                        #element.append(sub_e)
                    except:
                        pass
                tese[atributo] = element
    
    return(tese)

# %% [markdown]
# Como em alguns casos o resumo português e inglês se misturaram, foi implementado uma função para separar os textos misturados

# %%
# Função para separar resumos português e inglês
def separacao_port_engl(abstract):

    mix_sent = nltk.sent_tokenize(abstract)

    new_mix = []
    for sent in mix_sent:
        position = sent.find('.')
        if position != len(sent)-1:
            sent_1 = sent[:position+1]
            sent_2 = sent[position+1:]
            new_mix.append(sent_1)
            new_mix.append(sent_2)
        else:
            new_mix.append(sent)

    mix_sent = new_mix

    port = []
    engl = []

    for sent in mix_sent:
        try:
            if detect (sent) == 'pt':
                port.append(sent)
            else:
                engl.append (sent)
        except:
            pass

    port = " ".join(port)
    engl = " ".join(engl)

    return(port, engl)

# %% [markdown]
# Até esse momento estamos recuperando as informações de todas as teses de uma determinada instituição. No entanto o objetivo é gravar os metadados e salvar o arquivo apenas das teses relacionadas a O&G. Portanto, vamos carregar os algoritmos de classificação e de vetorização de palavras treinados previamente.

# %%
# Carregando modelo Word2Vec
BDTD_word2vec_50 = Word2Vec.load("..\..\..\Embeddings\BDTD_word2vec_50")
# Carregando modelo keras
model_keras = load_model('..\..\..\model_cnn.h5')
model_keras.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:131: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 400, 50)           9289150
# _________________________________________________________________
# spatial_dropout1d_6 (Spatial (None, 400, 50)           0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 396, 128)          32128
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 198, 128)          0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 198, 128)          0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 194, 128)          82048
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 97, 128)           0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 97, 128)           0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 93, 128)           82048
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 128)               0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               66048
# _________________________________________________________________
# dense_31 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 9,814,591
# Trainable params: 525,441
# Non-trainable params: 9,289,150
# _________________________________________________________________

# %%
# dicionário proveniente do modelo de word embedding para converter palavras em índices
word2index = {}
for index, word in enumerate(BDTD_word2vec_50.wv.index2word):
    word2index[word] = index
    
# Função para converter texto em sequência de índices
def index_pad_text(text, maxlen, word2index):
    maxlen = 400
    new_text = [] 
    
    for word in word_tokenize(text):
        try:
            new_text.append(word2index[word])
        except:
            pass
    # Add the padding for each sentence. Here I am padding with 0
    if len(new_text) > maxlen:
        new_text = new_text[:400]
    else:
        new_text += [0] * (maxlen - len(new_text))

    return np.array(new_text)

maxlen = 400

# %% [markdown]
# Para cada link coletado será fita as seguintes tarefas:
# * verificar se o texto português e inglês estão misturados;
# * transformar o texto em sequência de índices;
# * classificar quanto a relevância ao domínio de O&G;
# * se for relevante, gravar os metadados

# %%
# Dicionário para agrupar os metadados
metadados = {}
# Contadores te links testados e classificados como O&G
n_test = 0
n_pet = 0
# Testando cada link de links
for link in links:
    n_test += 1
    try:
        # Recuperar o metadados de uma tese
        metadado = tese_link(link)
        # Verificar se existe resumo em inglês, separar texto português/inglês e realocar 
        # os textos separados nas respectivas colunas
        if 'Resumo inglês:' not in metadado:
            metadado['Resumo inglês:'] = separacao_port_engl(metadado['Resumo Português:'])[1]
        metadado['Resumo Português:'] = separacao_port_engl(metadado['Resumo Português:'])[0]
        # Colocando o texto em minúscula
        text = metadado['Resumo Português:'].lower()
        # Convertendo as palavras em sequencias de acordo com o modelo word2vec
        text_seq = index_pad_text(text, maxlen, word2index)
        text_seq = text_seq.reshape((1, 400))
        # Usando o algoritmo classificador para prever se a tese é relevante
        pred = model_keras.predict(text_seq)[0]
        #Se a classificação for menor do que 0.2 manter os metadados
        if (pred < 0.2 and len(text) > 100):
            metadado['Classificador'] = pred[0]
            texto_completo = metadado['Download Texto Completo:']
            metadados[texto_completo] = metadado
            n_pet += 1
            # Gravando os resultados em JSON
            metadados_ufes = pd.DataFrame.from_dict(metadados, orient='index')
            metadados_ufes.to_json('metadados_ufes.json', orient = 'index')
            print(n_test, " teses avaliadas e ", n_pet, " teses relacionadas a O&G encontradas.")
    
    except:
        pass
# Out:
# 16  teses avaliadas e  1  teses relacionadas a O&G encontradas.
# 43  teses avaliadas e  2  teses relacionadas a O&G encontradas.
# 47  teses avaliadas e  3  teses relacionadas a O&G encontradas.
# 108  teses avaliadas e  4  teses relacionadas a O&G encontradas.
# 113  teses avaliadas e  5  teses relacionadas a O&G encontradas.
# 116  teses avaliadas e  6  teses relacionadas a O&G encontradas.
# 135  teses avaliadas e  7  teses relacionadas a O&G encontradas.
# 140  teses avaliadas e  8  teses relacionadas a O&G encontradas.
# 143  teses avaliadas e  9  teses relacionadas a O&G encontradas.
# 151  teses avaliadas e  10  teses relacionadas a O&G encontradas.
# 179  teses avaliadas e  11  teses relacionadas a O&G encontradas.
# 185  teses avaliadas e  12  teses relacionadas a O&G encontradas.
# 212  teses avaliadas e  13  teses relacionadas a O&G encontradas.
# 219  teses avaliadas e  14  teses relacionadas a O&G encontradas.
# 234  teses avaliadas e  15  teses relacionadas a O&G encontradas.
# 242  teses avaliadas e  16  teses relacionadas a O&G encontradas.
# 275  teses avaliadas e  17  teses relacionadas a O&G encontradas.
# 277  teses avaliadas e  18  teses relacionadas a O&G encontradas.
# 278  teses avaliadas e  19  teses relacionadas a O&G encontradas.
# 279  teses avaliadas e  20  teses relacionadas a O&G encontradas.
# 288  teses avaliadas e  21  teses relacionadas a O&G encontradas.
# 295  teses avaliadas e  22  teses relacionadas a O&G encontradas.
# 296  teses avaliadas e  23  teses relacionadas a O&G encontradas.
# 329  teses avaliadas e  24  teses relacionadas a O&G encontradas.
# 330  teses avaliadas e  25  teses relacionadas a O&G encontradas.
# 437  teses avaliadas e  26  teses relacionadas a O&G encontradas.
# 453  teses avaliadas e  27  teses relacionadas a O&G encontradas.
# 456  teses avaliadas e  28  teses relacionadas a O&G encontradas.
# 482  teses avaliadas e  29  teses relacionadas a O&G encontradas.
# 513  teses avaliadas e  30  teses relacionadas a O&G encontradas.
# 584  teses avaliadas e  31  teses relacionadas a O&G encontradas.
# 608  teses avaliadas e  32  teses relacionadas a O&G encontradas.
# 611  teses avaliadas e  33  teses relacionadas a O&G encontradas.
# 619  teses avaliadas e  34  teses relacionadas a O&G encontradas.
# 621  teses avaliadas e  35  teses relacionadas a O&G encontradas.
# 814  teses avaliadas e  36  teses relacionadas a O&G encontradas.
# 827  teses avaliadas e  37  teses relacionadas a O&G encontradas.
# 940  teses avaliadas e  38  teses relacionadas a O&G encontradas.
# 1027  teses avaliadas e  39  teses relacionadas a O&G encontradas.
# 1089  teses avaliadas e  40  teses relacionadas a O&G encontradas.
# 1127  teses avaliadas e  41  teses relacionadas a O&G encontradas.
# 1344  teses avaliadas e  42  teses relacionadas a O&G encontradas.
# 1352  teses avaliadas e  43  teses relacionadas a O&G encontradas.
# 1358  teses avaliadas e  44  teses relacionadas a O&G encontradas.
# 1443  teses avaliadas e  45  teses relacionadas a O&G encontradas.
# 1470  teses avaliadas e  46  teses relacionadas a O&G encontradas.
# 1479  teses avaliadas e  47  teses relacionadas a O&G encontradas.
# 1508  teses avaliadas e  48  teses relacionadas a O&G encontradas.
# 1514  teses avaliadas e  49  teses relacionadas a O&G encontradas.
# 1615  teses avaliadas e  50  teses relacionadas a O&G encontradas.
# 1952  teses avaliadas e  51  teses relacionadas a O&G encontradas.
# 1975  teses avaliadas e  52  teses relacionadas a O&G encontradas.
# 2199  teses avaliadas e  53  teses relacionadas a O&G encontradas.
# 2292  teses avaliadas e  54  teses relacionadas a O&G encontradas.
# 2492  teses avaliadas e  55  teses relacionadas a O&G encontradas.
# 2515  teses avaliadas e  56  teses relacionadas a O&G encontradas.
# 2660  teses avaliadas e  57  teses relacionadas a O&G encontradas.
# 2767  teses avaliadas e  58  teses relacionadas a O&G encontradas.
# 2849  teses avaliadas e  59  teses relacionadas a O&G encontradas.
# 3125  teses avaliadas e  60  teses relacionadas a O&G encontradas.
# 3132  teses avaliadas e  61  teses relacionadas a O&G encontradas.
# 3143  teses avaliadas e  62  teses relacionadas a O&G encontradas.
# 3161  teses avaliadas e  63  teses relacionadas a O&G encontradas.
# 3364  teses avaliadas e  64  teses relacionadas a O&G encontradas.
# 3932  teses avaliadas e  65  teses relacionadas a O&G encontradas.
# 4079  teses avaliadas e  66  teses relacionadas a O&G encontradas.
# 4103  teses avaliadas e  67  teses relacionadas a O&G encontradas.
# 4167  teses avaliadas e  68  teses relacionadas a O&G encontradas.
# 4251  teses avaliadas e  69  teses relacionadas a O&G encontradas.
# 4335  teses avaliadas e  70  teses relacionadas a O&G encontradas.
# 4367  teses avaliadas e  71  teses relacionadas a O&G encontradas.
# 4395  teses avaliadas e  72  teses relacionadas a O&G encontradas.
# 4483  teses avaliadas e  73  teses relacionadas a O&G encontradas.
# 4485  teses avaliadas e  74  teses relacionadas a O&G encontradas.
# 4486  teses avaliadas e  75  teses relacionadas a O&G encontradas.
# 4499  teses avaliadas e  76  teses relacionadas a O&G encontradas.
# 4514  teses avaliadas e  77  teses relacionadas a O&G encontradas.
# 4557  teses avaliadas e  78  teses relacionadas a O&G encontradas.
# 4717  teses avaliadas e  79  teses relacionadas a O&G encontradas.
# 4724  teses avaliadas e  80  teses relacionadas a O&G encontradas.
# 4763  teses avaliadas e  81  teses relacionadas a O&G encontradas.
# 4953  teses avaliadas e  82  teses relacionadas a O&G encontradas.
# 4987  teses avaliadas e  83  teses relacionadas a O&G encontradas.
# 4988  teses avaliadas e  84  teses relacionadas a O&G encontradas.
# 5065  teses avaliadas e  85  teses relacionadas a O&G encontradas.
# 5200  teses avaliadas e  86  teses relacionadas a O&G encontradas.
# 5246  teses avaliadas e  87  teses relacionadas a O&G encontradas.
# 5303  teses avaliadas e  88  teses relacionadas a O&G encontradas.
# 5304  teses avaliadas e  89  teses relacionadas a O&G encontradas.
# 5394  teses avaliadas e  90  teses relacionadas a O&G encontradas.
# 5410  teses avaliadas e  91  teses relacionadas a O&G encontradas.
# 5454  teses avaliadas e  92  teses relacionadas a O&G encontradas.
# 5494  teses avaliadas e  93  teses relacionadas a O&G encontradas.
# 5498  teses avaliadas e  94  teses relacionadas a O&G encontradas.
# 5600  teses avaliadas e  95  teses relacionadas a O&G encontradas.
# 5625  teses avaliadas e  96  teses relacionadas a O&G encontradas.
# 5641  teses avaliadas e  97  teses relacionadas a O&G encontradas.
# 5750  teses avaliadas e  98  teses relacionadas a O&G encontradas.
# 5808  teses avaliadas e  99  teses relacionadas a O&G encontradas.
# 5871  teses avaliadas e  100  teses relacionadas a O&G encontradas.
# 5875  teses avaliadas e  101  teses relacionadas a O&G encontradas.
# 5909  teses avaliadas e  102  teses relacionadas a O&G encontradas.
# 6026  teses avaliadas e  103  teses relacionadas a O&G encontradas.
# 6120  teses avaliadas e  104  teses relacionadas a O&G encontradas.
# 6143  teses avaliadas e  105  teses relacionadas a O&G encontradas.
# 6172  teses avaliadas e  106  teses relacionadas a O&G encontradas.
# 6186  teses avaliadas e  107  teses relacionadas a O&G encontradas.
# 6204  teses avaliadas e  108  teses relacionadas a O&G encontradas.
# 6207  teses avaliadas e  109  teses relacionadas a O&G encontradas.
# 6273  teses avaliadas e  110  teses relacionadas a O&G encontradas.
# 6423  teses avaliadas e  111  teses relacionadas a O&G encontradas.
# 6443  teses avaliadas e  112  teses relacionadas a O&G encontradas.
# 6526  teses avaliadas e  113  teses relacionadas a O&G encontradas.
# 6529  teses avaliadas e  114  teses relacionadas a O&G encontradas.
# 6552  teses avaliadas e  115  teses relacionadas a O&G encontradas.
# 6567  teses avaliadas e  116  teses relacionadas a O&G encontradas.
# 6599  teses avaliadas e  117  teses relacionadas a O&G encontradas.
# 6602  teses avaliadas e  118  teses relacionadas a O&G encontradas.
# 6695  teses avaliadas e  119  teses relacionadas a O&G encontradas.
# 6717  teses avaliadas e  120  teses relacionadas a O&G encontradas.
# 6721  teses avaliadas e  121  teses relacionadas a O&G encontradas.
# 6861  teses avaliadas e  122  teses relacionadas a O&G encontradas.
# 6862  teses avaliadas e  123  teses relacionadas a O&G encontradas.
# 6949  teses avaliadas e  124  teses relacionadas a O&G encontradas.
# 6991  teses avaliadas e  125  teses relacionadas a O&G encontradas.
# 7038  teses avaliadas e  126  teses relacionadas a O&G encontradas.
# 7048  teses avaliadas e  127  teses relacionadas a O&G encontradas.
# 7188  teses avaliadas e  128  teses relacionadas a O&G encontradas.
# 7242  teses avaliadas e  129  teses relacionadas a O&G encontradas.
# 7249  teses avaliadas e  130  teses relacionadas a O&G encontradas.
# 7399  teses avaliadas e  131  teses relacionadas a O&G encontradas.
# 7406  teses avaliadas e  132  teses relacionadas a O&G encontradas.
# 7465  teses avaliadas e  133  teses relacionadas a O&G encontradas.
# 7702  teses avaliadas e  134  teses relacionadas a O&G encontradas.
# 7766  teses avaliadas e  135  teses relacionadas a O&G encontradas.
# 7986  teses avaliadas e  136  teses relacionadas a O&G encontradas.
# 7989  teses avaliadas e  137  teses relacionadas a O&G encontradas.
# 7999  teses avaliadas e  138  teses relacionadas a O&G encontradas.
# 8061  teses avaliadas e  139  teses relacionadas a O&G encontradas.
# 8161  teses avaliadas e  140  teses relacionadas a O&G encontradas.
# 8172  teses avaliadas e  141  teses relacionadas a O&G encontradas.
# 8215  teses avaliadas e  142  teses relacionadas a O&G encontradas.
# 8253  teses avaliadas e  143  teses relacionadas a O&G encontradas.
# 8255  teses avaliadas e  144  teses relacionadas a O&G encontradas.
# 8275  teses avaliadas e  145  teses relacionadas a O&G encontradas.
# 8393  teses avaliadas e  146  teses relacionadas a O&G encontradas.
# 8394  teses avaliadas e  147  teses relacionadas a O&G encontradas.
# 8539  teses avaliadas e  148  teses relacionadas a O&G encontradas.
# 8540  teses avaliadas e  149  teses relacionadas a O&G encontradas.
# 8541  teses avaliadas e  150  teses relacionadas a O&G encontradas.
# 8542  teses avaliadas e  151  teses relacionadas a O&G encontradas.
# 8550  teses avaliadas e  152  teses relacionadas a O&G encontradas.

# %%
# Incluindo um ID para cada tese
universidade = 'UFES'
metadados_ufes['PDF_ID'] = metadados_ufes['Download Texto Completo:'].apply(lambda x: universidade + 
                                                                            '_' + 
                                                                            re.sub('/', '_', x[-7:]))

# %%
metadados_ufes.to_json('metadados_ufes.json', orient = 'index')

# %%
# Carregando arquivos já gravados
metadados_ufes = pd.read_json('metadados_ufes.json', orient = 'index')

# %% [markdown]
# A próxima etapa será fazer o download das teses classificadas como relevante para o domínio de O&G

# %%
for tese in metadados_ufes.iterrows():
    print(tese[1]['PDF_ID'])
    try:
        #preparar a url
        url = tese[1]['Download Texto Completo:']

        #Fazer requisição e parsear o arquivo html
        f = requests.get(url, proxies = proxies).text 
        soup = bs(f, "html.parser")

        #Coletando link para arquivo das teses
        links = []
        for doc in soup.find_all('a', href=True):
            if doc.get_text() == 'View/Open':
                links.append(doc['href'])

        #Recuperando e gravando arquivo PDF
        url = 'http://repositorio.ufes.br' + links[0]
        pdf = requests.get(url, proxies = proxies)
        filename = tese[1]['PDF_ID'] + '.pdf'
        with open(filename, 'wb') as f:
            f.write(pdf.content)
    except:
        pass
# Out:
# UFPE__18766
# UFPE__18867
# UFPE__19021
# UFPE__19023
# UFPE__19634
# UFPE__19682
# UFPE__20272
# UFPE__22404
# UFPE__23461
# UFPE__23485
# UFPE__23757
# UFPE__23920
# UFPE__24074
# UFPE__24425
# UFPE__24501
# UFPE__24547
# UFPE__24570
# UFPE__24861
# UFPE__24963
# UFPE__24967
# UFPE__25097
# UFPE__25099
# UFPE__25160
# UFPE__25202
# UFPE__25206
# UFPE__25280
# UFPE__25295
# UFPE__25320
# UFPE__25488
# UFPE__25493
# UFPE__25512
# UFPE__25589
# UFPE__25593
# UFPE__25667
# UFPE__25671
# UFPE__25992
# UFPE__26032
# UFPE__26310
# UFPE__26319
# UFPE__26325
# UFPE__26644
# UFPE__26807
# UFPE__26888
# UFPE__26905
# UFPE__26906
# UFPE__27569
# UFPE__27894
# UFPE__28012
# UFPE__28075
# UFPE__28078
# UFPE__28344
# UFPE__28380
# UFPE__28388
# UFPE__28397
# UFPE__28988
# UFPE__29110
# UFPE__29111
# UFPE__29225
# UFPE__29620
# UFPE__29709
# UFPE__29749
# UFPE__29775
# UFPE__29778
# UFPE__29825
# UFPE__29854
# UFPE__29894
# UFPE__29913
# UFPE__30013
# UFPE__30342
# UFPE__30396
# UFPE__30558
# UFPE__30567
# UFPE__30608
# UFPE__30739
# UFPE__31060
# UFPE__31107
# UFPE__31119
# UFPE__31657
# UFPE__31667
# UFPE__31702
# UFPE__32058
# UFPE__32123
# UFPE__32240
# UFPE__32242
# UFPE__32272
# UFPE__32274
# UFPE__32304
# UFPE__32488
# UFPE__32490
# UFPE__32496
# UFPE__32572
# UFPE__32835
# UFPE__34454
# UFPE__34455
# UFPE__34482
# UFPE__34494
# UFPE__34499
# UFPE__34504
# UFPE__34505
# UFPE_9_4304
# UFPE_9_4317
# UFPE_9_4379
# UFPE_9_4418
# UFPE_9_4531
# UFPE_9_4619
# UFPE_9_4882
# UFPE_9_4902
# UFPE_9_4905
# UFPE_9_4916
# UFPE_9_4928
# UFPE_9_4945
# UFPE_9_4948
# UFPE_9_4962
# UFPE_9_4979
# UFPE_9_5014
# UFPE_9_5441
# UFPE_9_5446
# UFPE_9_5447
# UFPE_9_5454
# UFPE_9_5484
# UFPE_9_5488
# UFPE_9_5518
# UFPE_9_5525
# UFPE_9_5623
# UFPE_9_5751
# UFPE_9_5758
# UFPE_9_5833
# UFPE_9_5838
# UFPE_9_5841
# UFPE_9_5859
# UFPE_9_5867
# UFPE_9_5903
# UFPE_9_5905
# UFPE_9_5906
# UFPE_9_5907
# UFPE_9_5916
# UFPE_9_5923
# UFPE_9_5924
# UFPE_9_5957
# UFPE_9_5958
# UFPE_9_6877
# UFPE_9_6883
# UFPE_9_6893
# UFPE_9_6913
# UFPE_9_7321
# UFPE_9_8017
# UFPE_9_9117
# UFPE_9_9619
# UFPE_9_9644
# UFPE_9_9792
# UFPE_9_9901
# UFPE_9_9983
