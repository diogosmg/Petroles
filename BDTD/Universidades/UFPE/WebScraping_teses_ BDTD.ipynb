# %% [markdown]
# Script para buscar resumos das teses elaboradas pelos empregados da Petrobras

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import json
import nltk
from nltk.tokenize import word_tokenize
from langdetect import detect
from langdetect import detect_langs
from keras.models import load_model
import gensim
from gensim.models import Word2Vec
import csv
import re

# %%
# Definindo configurações globais de proxy para realizar a extração dentro da rede Petrobras
chave = 'upe2'
pwd = 'fBO61291'
proxy_url = 'http://'+chave+':'+pwd+'@inet-sys.gnet.petrobras.com.br:804/'
proxies = {
  'http' : proxy_url ,
  'https' : proxy_url ,
}

# %% [markdown]
# Inicialmente entraremos no site da BDTD e buscaremos os links de todas as teses de uma determinada intituição.

# %%
#função para coletar os links das tese

def get_links(page):
        
    #preparar a url
    url = ('http://bdtd.ibict.br/vufind/Search/Results?filter%5B%5D=institution%3A%22UFPE%22&type=AllFields&page=' +
           str(page))
    
    #Fazer requisição e parsear o arquivo html
    f = requests.get(url, proxies = proxies).text 
    soup = bs(f, "html.parser")

    #Coletando link para as teses
    links = []
    for doc in soup.find_all('a', href=True):
        if 'title' in doc.get('class', []):
            links.append(doc['href'])
    return links

# %%
#Coletar o link de todas as teses
start_page = 1
n_pages = 600 # Cada página retorna 20 teses

links = []

for p in range(start_page, n_pages):
    link = get_links(p)
    if link != []:
        links = links + link
    else:
        break
    
    if p % 100 == 0:
        print (p*20, ' links capturados, ', p, ' páginas')
        with open('links_ufpe', "w") as output:
            writer = csv.writer(output, lineterminator='\n')
            for val in links:
                writer.writerow([val])
                
with open('links_ufpe', "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in links:
        writer.writerow([val]) 
print (p*20, ' links capturados, ', p, ' páginas')
# Out:
# 2000  links capturados,  100  páginas
# 4000  links capturados,  200  páginas
# 6000  links capturados,  300  páginas
# 8000  links capturados,  400  páginas
# 10000  links capturados,  500  páginas
# 11980  links capturados,  599  páginas

# %%
# Abrindo arquivo gravado anteriormente

#links = []
#with open('links_ufpe', 'r') as f:
#    reader = csv.reader(f)
#    for link in reader:
#        links.append(link[0])

# %% [markdown]
# Em seguida vamos recuperar os metadados de cada link coletado anteriormente.

# %%
#função para buscar os metadados das teses no BDTD
def tese_link(link):
    #definir url
    url = 'http://bdtd.ibict.br' + link
    
    #Requisitar html e fazer o parser
    f = requests.get(url, proxies = proxies).text 
    soup = bs(f, "html.parser")

    #Dicionário para armazenar as informações da tese
    tese = {}  
    
    #Adicionar título
    tese['Title'] = soup.find('h3').get_text()
    for doc in soup.find_all('tr'):
        #Identificar atributo
        try:
            atributo = doc.find('th').get_text()
        except:
            pass
        #Verificar se o atributo possui mais de um dado
        for row in doc.find_all('td'):
            #Adicionar o atributo no dicionário
            if row.find('div') == None:
                try:
                    tese[atributo] = doc.find('td').get_text()
                except:
                    pass
            else:
                element = []
                #No dicionário, adicionar todos os dados ao seu respectivo atributo
                for e in doc.find_all('div'):
                    try:
                        sub_e = []
                        for sub_element in e.find_all('a'):
                            element.append(sub_element.get_text()) 
                        #element.append(sub_e)
                    except:
                        pass
                tese[atributo] = element
    
    return(tese)

# %% [markdown]
# Como em alguns casos o resumo português e inglês se misturaram, foi implementado uma função para separar os textos misturados

# %%
# Função para separar resumos português e inglês
def separacao_port_engl(abstract):

    mix_sent = nltk.sent_tokenize(abstract)

    new_mix = []
    for sent in mix_sent:
        position = sent.find('.')
        if position != len(sent)-1:
            sent_1 = sent[:position+1]
            sent_2 = sent[position+1:]
            new_mix.append(sent_1)
            new_mix.append(sent_2)
        else:
            new_mix.append(sent)

    mix_sent = new_mix

    port = []
    engl = []

    for sent in mix_sent:
        try:
            if detect (sent) == 'pt':
                port.append(sent)
            else:
                engl.append (sent)
        except:
            pass

    port = " ".join(port)
    engl = " ".join(engl)

    return(port, engl)

# %% [markdown]
# Até esse momento estamos recuperando as informações de todas as teses de uma determinada instituição. No entanto o objetivo é gravar os metadados e salvar o arquivo apenas das teses relacionadas a O&G. Portanto, vamos carregar os algoritmos de classificação e de vetorização de palavras treinados previamente.

# %%
# Carregando modelo Word2Vec
BDTD_word2vec_50 = Word2Vec.load("..\..\..\Embeddings\BDTD_word2vec_50")
# Carregando modelo keras
model_keras = load_model('..\..\..\model_cnn.h5')
model_keras.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:131: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 400, 50)           9289150
# _________________________________________________________________
# spatial_dropout1d_6 (Spatial (None, 400, 50)           0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 396, 128)          32128
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 198, 128)          0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 198, 128)          0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 194, 128)          82048
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 97, 128)           0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 97, 128)           0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 93, 128)           82048
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 128)               0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               66048
# _________________________________________________________________
# dense_31 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 9,814,591
# Trainable params: 525,441
# Non-trainable params: 9,289,150
# _________________________________________________________________

# %%
# dicionário proveniente do modelo de word embedding para converter palavras em índices
word2index = {}
for index, word in enumerate(BDTD_word2vec_50.wv.index2word):
    word2index[word] = index
    
# Função para converter texto em sequência de índices
def index_pad_text(text, maxlen, word2index):
    maxlen = 400
    new_text = [] 
    
    for word in word_tokenize(text):
        try:
            new_text.append(word2index[word])
        except:
            pass
    # Add the padding for each sentence. Here I am padding with 0
    if len(new_text) > maxlen:
        new_text = new_text[:400]
    else:
        new_text += [0] * (maxlen - len(new_text))

    return np.array(new_text)

maxlen = 400

# %% [markdown]
# Para cada link coletado será fita as seguintes tarefas:
# * verificar se o texto português e inglês estão misturados;
# * transformar o texto em sequência de índices;
# * classificar quanto a relevância ao domínio de O&G;
# * se for relevante, gravar os metadados

# %%
# Dicionário para agrupar os metadados
metadados = {}
# Contadores te links testados e classificados como O&G
n_test = 0
n_pet = 0
# Testando cada link de links
for link in links:
    n_test += 1
    try:
        # Recuperar o metadados de uma tese
        metadado = tese_link(link)
        # Verificar se existe resumo em inglês, separar texto português/inglês e realocar 
        # os textos separados nas respectivas colunas
        if 'Resumo inglês:' not in metadado:
            metadado['Resumo inglês:'] = separacao_port_engl(metadado['Resumo Português:'])[1]
        metadado['Resumo Português:'] = separacao_port_engl(metadado['Resumo Português:'])[0]
        # Colocando o texto em minúscula
        text = metadado['Resumo Português:'].lower()
        # Convertendo as palavras em sequencias de acordo com o modelo word2vec
        text_seq = index_pad_text(text, maxlen, word2index)
        text_seq = text_seq.reshape((1, 400))
        # Usando o algoritmo classificador para prever se a tese é relevante
        pred = model_keras.predict(text_seq)[0]
        #Se a classificação for menor do que 0.2 manter os metadados
        if (pred < 0.2 and len(text) > 100):
            metadado['Classificador'] = pred[0]
            texto_completo = metadado['Download Texto Completo:']
            metadados[texto_completo] = metadado
            n_pet += 1
            # Gravando os resultados em JSON
            metadados_ufpe = pd.DataFrame.from_dict(metadados, orient='index')
            metadados_ufpe.to_json('metadados_ufpe_1.json', orient = 'index')
            print(n_test, " teses avaliadas e ", n_pet, " teses relacionadas a O&G encontradas.")
    
    except:
        pass
# Out:
# 74  teses avaliadas e  1  teses relacionadas a O&G encontradas.
# 241  teses avaliadas e  2  teses relacionadas a O&G encontradas.
# 283  teses avaliadas e  3  teses relacionadas a O&G encontradas.
# 294  teses avaliadas e  4  teses relacionadas a O&G encontradas.
# 346  teses avaliadas e  5  teses relacionadas a O&G encontradas.
# 348  teses avaliadas e  6  teses relacionadas a O&G encontradas.
# 390  teses avaliadas e  7  teses relacionadas a O&G encontradas.
# 405  teses avaliadas e  8  teses relacionadas a O&G encontradas.
# 419  teses avaliadas e  9  teses relacionadas a O&G encontradas.
# 420  teses avaliadas e  10  teses relacionadas a O&G encontradas.
# 450  teses avaliadas e  11  teses relacionadas a O&G encontradas.
# 494  teses avaliadas e  12  teses relacionadas a O&G encontradas.
# 536  teses avaliadas e  13  teses relacionadas a O&G encontradas.
# 685  teses avaliadas e  14  teses relacionadas a O&G encontradas.
# 821  teses avaliadas e  15  teses relacionadas a O&G encontradas.
# 822  teses avaliadas e  16  teses relacionadas a O&G encontradas.
# 830  teses avaliadas e  17  teses relacionadas a O&G encontradas.
# 852  teses avaliadas e  18  teses relacionadas a O&G encontradas.
# 1121  teses avaliadas e  19  teses relacionadas a O&G encontradas.
# 1189  teses avaliadas e  20  teses relacionadas a O&G encontradas.
# 1212  teses avaliadas e  21  teses relacionadas a O&G encontradas.
# 1296  teses avaliadas e  22  teses relacionadas a O&G encontradas.
# 1342  teses avaliadas e  23  teses relacionadas a O&G encontradas.
# 1356  teses avaliadas e  24  teses relacionadas a O&G encontradas.
# 1365  teses avaliadas e  25  teses relacionadas a O&G encontradas.
# 1369  teses avaliadas e  26  teses relacionadas a O&G encontradas.
# 1370  teses avaliadas e  27  teses relacionadas a O&G encontradas.
# 1407  teses avaliadas e  28  teses relacionadas a O&G encontradas.
# 1464  teses avaliadas e  29  teses relacionadas a O&G encontradas.
# 1587  teses avaliadas e  30  teses relacionadas a O&G encontradas.
# 1599  teses avaliadas e  31  teses relacionadas a O&G encontradas.
# 1625  teses avaliadas e  32  teses relacionadas a O&G encontradas.
# 1676  teses avaliadas e  33  teses relacionadas a O&G encontradas.
# 1716  teses avaliadas e  34  teses relacionadas a O&G encontradas.
# 1784  teses avaliadas e  35  teses relacionadas a O&G encontradas.
# 1807  teses avaliadas e  36  teses relacionadas a O&G encontradas.
# 1975  teses avaliadas e  37  teses relacionadas a O&G encontradas.
# 2044  teses avaliadas e  38  teses relacionadas a O&G encontradas.
# 2097  teses avaliadas e  39  teses relacionadas a O&G encontradas.
# 2198  teses avaliadas e  40  teses relacionadas a O&G encontradas.
# 2209  teses avaliadas e  41  teses relacionadas a O&G encontradas.
# 2226  teses avaliadas e  42  teses relacionadas a O&G encontradas.
# 2233  teses avaliadas e  43  teses relacionadas a O&G encontradas.
# 2458  teses avaliadas e  44  teses relacionadas a O&G encontradas.
# 2501  teses avaliadas e  45  teses relacionadas a O&G encontradas.
# 2514  teses avaliadas e  46  teses relacionadas a O&G encontradas.
# 2745  teses avaliadas e  47  teses relacionadas a O&G encontradas.
# 2751  teses avaliadas e  48  teses relacionadas a O&G encontradas.
# 3101  teses avaliadas e  49  teses relacionadas a O&G encontradas.
# 3133  teses avaliadas e  50  teses relacionadas a O&G encontradas.
# 3142  teses avaliadas e  51  teses relacionadas a O&G encontradas.
# 3160  teses avaliadas e  52  teses relacionadas a O&G encontradas.
# 3175  teses avaliadas e  53  teses relacionadas a O&G encontradas.
# 3200  teses avaliadas e  54  teses relacionadas a O&G encontradas.
# 3245  teses avaliadas e  55  teses relacionadas a O&G encontradas.
# 3260  teses avaliadas e  56  teses relacionadas a O&G encontradas.
# 3267  teses avaliadas e  57  teses relacionadas a O&G encontradas.
# 3280  teses avaliadas e  58  teses relacionadas a O&G encontradas.
# 3296  teses avaliadas e  59  teses relacionadas a O&G encontradas.
# 3298  teses avaliadas e  60  teses relacionadas a O&G encontradas.
# 3307  teses avaliadas e  61  teses relacionadas a O&G encontradas.
# 3425  teses avaliadas e  62  teses relacionadas a O&G encontradas.
# 3446  teses avaliadas e  63  teses relacionadas a O&G encontradas.
# 3453  teses avaliadas e  64  teses relacionadas a O&G encontradas.
# 3489  teses avaliadas e  65  teses relacionadas a O&G encontradas.
# 3501  teses avaliadas e  66  teses relacionadas a O&G encontradas.
# 3686  teses avaliadas e  67  teses relacionadas a O&G encontradas.
# 3739  teses avaliadas e  68  teses relacionadas a O&G encontradas.
# 3741  teses avaliadas e  69  teses relacionadas a O&G encontradas.
# 3744  teses avaliadas e  70  teses relacionadas a O&G encontradas.
# 3888  teses avaliadas e  71  teses relacionadas a O&G encontradas.
# 3915  teses avaliadas e  72  teses relacionadas a O&G encontradas.
# 3923  teses avaliadas e  73  teses relacionadas a O&G encontradas.
# 3979  teses avaliadas e  74  teses relacionadas a O&G encontradas.
# 4005  teses avaliadas e  75  teses relacionadas a O&G encontradas.
# 4050  teses avaliadas e  76  teses relacionadas a O&G encontradas.
# 4059  teses avaliadas e  77  teses relacionadas a O&G encontradas.
# 4064  teses avaliadas e  78  teses relacionadas a O&G encontradas.
# 4071  teses avaliadas e  79  teses relacionadas a O&G encontradas.
# 4114  teses avaliadas e  80  teses relacionadas a O&G encontradas.
# 4252  teses avaliadas e  81  teses relacionadas a O&G encontradas.
# 4368  teses avaliadas e  82  teses relacionadas a O&G encontradas.
# 4428  teses avaliadas e  83  teses relacionadas a O&G encontradas.
# 4436  teses avaliadas e  84  teses relacionadas a O&G encontradas.
# 4438  teses avaliadas e  85  teses relacionadas a O&G encontradas.
# 4441  teses avaliadas e  86  teses relacionadas a O&G encontradas.
# 4445  teses avaliadas e  87  teses relacionadas a O&G encontradas.
# 4543  teses avaliadas e  88  teses relacionadas a O&G encontradas.
# 4576  teses avaliadas e  89  teses relacionadas a O&G encontradas.
# 4603  teses avaliadas e  90  teses relacionadas a O&G encontradas.
# 4607  teses avaliadas e  91  teses relacionadas a O&G encontradas.
# 4640  teses avaliadas e  92  teses relacionadas a O&G encontradas.
# 4689  teses avaliadas e  93  teses relacionadas a O&G encontradas.
# 4776  teses avaliadas e  94  teses relacionadas a O&G encontradas.
# 4787  teses avaliadas e  95  teses relacionadas a O&G encontradas.
# 4838  teses avaliadas e  96  teses relacionadas a O&G encontradas.
# 4942  teses avaliadas e  97  teses relacionadas a O&G encontradas.
# 5059  teses avaliadas e  98  teses relacionadas a O&G encontradas.
# 5060  teses avaliadas e  99  teses relacionadas a O&G encontradas.
# 5106  teses avaliadas e  100  teses relacionadas a O&G encontradas.
# 5150  teses avaliadas e  101  teses relacionadas a O&G encontradas.
# 5168  teses avaliadas e  102  teses relacionadas a O&G encontradas.
# 5177  teses avaliadas e  103  teses relacionadas a O&G encontradas.
# 5186  teses avaliadas e  104  teses relacionadas a O&G encontradas.
# 5191  teses avaliadas e  105  teses relacionadas a O&G encontradas.
# 5216  teses avaliadas e  106  teses relacionadas a O&G encontradas.
# 5224  teses avaliadas e  107  teses relacionadas a O&G encontradas.
# 5540  teses avaliadas e  108  teses relacionadas a O&G encontradas.
# 5634  teses avaliadas e  109  teses relacionadas a O&G encontradas.
# 5635  teses avaliadas e  110  teses relacionadas a O&G encontradas.
# 5636  teses avaliadas e  111  teses relacionadas a O&G encontradas.
# 5637  teses avaliadas e  112  teses relacionadas a O&G encontradas.
# 5781  teses avaliadas e  113  teses relacionadas a O&G encontradas.
# 5943  teses avaliadas e  114  teses relacionadas a O&G encontradas.
# 6069  teses avaliadas e  115  teses relacionadas a O&G encontradas.
# 6359  teses avaliadas e  116  teses relacionadas a O&G encontradas.
# 6417  teses avaliadas e  117  teses relacionadas a O&G encontradas.
# 6510  teses avaliadas e  118  teses relacionadas a O&G encontradas.
# 6521  teses avaliadas e  119  teses relacionadas a O&G encontradas.
# 6526  teses avaliadas e  120  teses relacionadas a O&G encontradas.
# 6784  teses avaliadas e  121  teses relacionadas a O&G encontradas.
# 6955  teses avaliadas e  122  teses relacionadas a O&G encontradas.
# 6965  teses avaliadas e  123  teses relacionadas a O&G encontradas.
# 6975  teses avaliadas e  124  teses relacionadas a O&G encontradas.
# 7064  teses avaliadas e  125  teses relacionadas a O&G encontradas.
# 7085  teses avaliadas e  126  teses relacionadas a O&G encontradas.
# 7129  teses avaliadas e  127  teses relacionadas a O&G encontradas.
# 7136  teses avaliadas e  128  teses relacionadas a O&G encontradas.
# 7146  teses avaliadas e  129  teses relacionadas a O&G encontradas.
# 7172  teses avaliadas e  130  teses relacionadas a O&G encontradas.
# 7187  teses avaliadas e  131  teses relacionadas a O&G encontradas.
# 7216  teses avaliadas e  132  teses relacionadas a O&G encontradas.
# 7237  teses avaliadas e  133  teses relacionadas a O&G encontradas.
# 7248  teses avaliadas e  134  teses relacionadas a O&G encontradas.
# 7261  teses avaliadas e  135  teses relacionadas a O&G encontradas.
# 7270  teses avaliadas e  136  teses relacionadas a O&G encontradas.
# 7280  teses avaliadas e  137  teses relacionadas a O&G encontradas.
# 7319  teses avaliadas e  138  teses relacionadas a O&G encontradas.
# 7322  teses avaliadas e  139  teses relacionadas a O&G encontradas.
# 7351  teses avaliadas e  140  teses relacionadas a O&G encontradas.
# 7393  teses avaliadas e  141  teses relacionadas a O&G encontradas.
# 7402  teses avaliadas e  142  teses relacionadas a O&G encontradas.
# 7438  teses avaliadas e  143  teses relacionadas a O&G encontradas.
# 7458  teses avaliadas e  144  teses relacionadas a O&G encontradas.
# 7473  teses avaliadas e  145  teses relacionadas a O&G encontradas.
# 7482  teses avaliadas e  146  teses relacionadas a O&G encontradas.
# 7501  teses avaliadas e  147  teses relacionadas a O&G encontradas.
# 7506  teses avaliadas e  148  teses relacionadas a O&G encontradas.
# 7532  teses avaliadas e  149  teses relacionadas a O&G encontradas.
# 7538  teses avaliadas e  150  teses relacionadas a O&G encontradas.
# 7545  teses avaliadas e  151  teses relacionadas a O&G encontradas.
# 7576  teses avaliadas e  152  teses relacionadas a O&G encontradas.
# 7596  teses avaliadas e  153  teses relacionadas a O&G encontradas.
# 7619  teses avaliadas e  154  teses relacionadas a O&G encontradas.
# 7623  teses avaliadas e  155  teses relacionadas a O&G encontradas.
# 7642  teses avaliadas e  156  teses relacionadas a O&G encontradas.
# 7645  teses avaliadas e  157  teses relacionadas a O&G encontradas.
# 7668  teses avaliadas e  158  teses relacionadas a O&G encontradas.
# 7680  teses avaliadas e  159  teses relacionadas a O&G encontradas.
# 7687  teses avaliadas e  160  teses relacionadas a O&G encontradas.
# 7722  teses avaliadas e  161  teses relacionadas a O&G encontradas.
# 7786  teses avaliadas e  162  teses relacionadas a O&G encontradas.
# 7813  teses avaliadas e  163  teses relacionadas a O&G encontradas.
# 7841  teses avaliadas e  164  teses relacionadas a O&G encontradas.
# 7868  teses avaliadas e  165  teses relacionadas a O&G encontradas.
# 8212  teses avaliadas e  166  teses relacionadas a O&G encontradas.
# 8241  teses avaliadas e  167  teses relacionadas a O&G encontradas.
# 8261  teses avaliadas e  168  teses relacionadas a O&G encontradas.
# 8304  teses avaliadas e  169  teses relacionadas a O&G encontradas.
# 8312  teses avaliadas e  170  teses relacionadas a O&G encontradas.
# 8335  teses avaliadas e  171  teses relacionadas a O&G encontradas.
# 8609  teses avaliadas e  172  teses relacionadas a O&G encontradas.
# 8679  teses avaliadas e  173  teses relacionadas a O&G encontradas.
# 8769  teses avaliadas e  174  teses relacionadas a O&G encontradas.
# 9353  teses avaliadas e  175  teses relacionadas a O&G encontradas.
# 9407  teses avaliadas e  176  teses relacionadas a O&G encontradas.
# 9426  teses avaliadas e  177  teses relacionadas a O&G encontradas.
# 9488  teses avaliadas e  178  teses relacionadas a O&G encontradas.
# 9601  teses avaliadas e  179  teses relacionadas a O&G encontradas.
# 9693  teses avaliadas e  180  teses relacionadas a O&G encontradas.
# 9830  teses avaliadas e  181  teses relacionadas a O&G encontradas.
# 9856  teses avaliadas e  182  teses relacionadas a O&G encontradas.
# 9913  teses avaliadas e  183  teses relacionadas a O&G encontradas.
# 10118  teses avaliadas e  184  teses relacionadas a O&G encontradas.
# 10187  teses avaliadas e  185  teses relacionadas a O&G encontradas.
# 10218  teses avaliadas e  186  teses relacionadas a O&G encontradas.
# 10233  teses avaliadas e  187  teses relacionadas a O&G encontradas.
# 10753  teses avaliadas e  188  teses relacionadas a O&G encontradas.
# 10809  teses avaliadas e  189  teses relacionadas a O&G encontradas.
# 10916  teses avaliadas e  190  teses relacionadas a O&G encontradas.
# 10977  teses avaliadas e  191  teses relacionadas a O&G encontradas.
# 11233  teses avaliadas e  192  teses relacionadas a O&G encontradas.
# 11434  teses avaliadas e  193  teses relacionadas a O&G encontradas.
# 11491  teses avaliadas e  194  teses relacionadas a O&G encontradas.
# 11502  teses avaliadas e  195  teses relacionadas a O&G encontradas.
# 11509  teses avaliadas e  196  teses relacionadas a O&G encontradas.
# 11534  teses avaliadas e  197  teses relacionadas a O&G encontradas.
# 11535  teses avaliadas e  198  teses relacionadas a O&G encontradas.
# 11537  teses avaliadas e  199  teses relacionadas a O&G encontradas.
# 11539  teses avaliadas e  200  teses relacionadas a O&G encontradas.
# 11542  teses avaliadas e  201  teses relacionadas a O&G encontradas.
# 11554  teses avaliadas e  202  teses relacionadas a O&G encontradas.
# 11571  teses avaliadas e  203  teses relacionadas a O&G encontradas.
# 11577  teses avaliadas e  204  teses relacionadas a O&G encontradas.
# 11578  teses avaliadas e  205  teses relacionadas a O&G encontradas.
# 11637  teses avaliadas e  206  teses relacionadas a O&G encontradas.
# 11685  teses avaliadas e  207  teses relacionadas a O&G encontradas.
# 11688  teses avaliadas e  208  teses relacionadas a O&G encontradas.
# 11696  teses avaliadas e  209  teses relacionadas a O&G encontradas.
# 11705  teses avaliadas e  210  teses relacionadas a O&G encontradas.
# 11708  teses avaliadas e  211  teses relacionadas a O&G encontradas.
# 11714  teses avaliadas e  212  teses relacionadas a O&G encontradas.
# 11717  teses avaliadas e  213  teses relacionadas a O&G encontradas.
# 11739  teses avaliadas e  214  teses relacionadas a O&G encontradas.
# 11751  teses avaliadas e  215  teses relacionadas a O&G encontradas.
# 11756  teses avaliadas e  216  teses relacionadas a O&G encontradas.
# 11758  teses avaliadas e  217  teses relacionadas a O&G encontradas.
# 11762  teses avaliadas e  218  teses relacionadas a O&G encontradas.
# 11763  teses avaliadas e  219  teses relacionadas a O&G encontradas.
# 11764  teses avaliadas e  220  teses relacionadas a O&G encontradas.
# 11767  teses avaliadas e  221  teses relacionadas a O&G encontradas.
# 11771  teses avaliadas e  222  teses relacionadas a O&G encontradas.
# 11789  teses avaliadas e  223  teses relacionadas a O&G encontradas.
# 11794  teses avaliadas e  224  teses relacionadas a O&G encontradas.
# 11796  teses avaliadas e  225  teses relacionadas a O&G encontradas.
# 11820  teses avaliadas e  226  teses relacionadas a O&G encontradas.
# 11853  teses avaliadas e  227  teses relacionadas a O&G encontradas.
# 11857  teses avaliadas e  228  teses relacionadas a O&G encontradas.
# 11862  teses avaliadas e  229  teses relacionadas a O&G encontradas.
# 11869  teses avaliadas e  230  teses relacionadas a O&G encontradas.
# 11873  teses avaliadas e  231  teses relacionadas a O&G encontradas.
# 11899  teses avaliadas e  232  teses relacionadas a O&G encontradas.
# 11915  teses avaliadas e  233  teses relacionadas a O&G encontradas.
# 11945  teses avaliadas e  234  teses relacionadas a O&G encontradas.
# 11956  teses avaliadas e  235  teses relacionadas a O&G encontradas.
# 11959  teses avaliadas e  236  teses relacionadas a O&G encontradas.

# %%
# Incluindo um ID para cada tese
universidade = 'UFPE'
metadados_ufpe['PDF_ID'] = metadados_ufpe['Download Texto Completo:'].apply(lambda x: universidade + 
                                                                            '_' + 
                                                                            re.sub('/', '_', x[-6:]))

# %%
metadados_ufpe.to_json('metadados_ufpe_1.json', orient = 'index')

# %%
# Carregando arquivos já gravados
metadados_ufpe = pd.read_json('metadados_ufpe_1.json', orient = 'index')

# %% [markdown]
# A próxima etapa será fazer o download das teses classificadas como relevante para o domínio de O&G

# %%
for tese in metadados_ufpe.iterrows():
    try:
        #preparar a url
        url = tese[1]['Download Texto Completo:']

        #Fazer requisição e parsear o arquivo html
        f = requests.get(url, proxies = proxies).text 
        soup = bs(f, "html.parser")

        #Coletando link para arquivo das teses
        links = []
        for doc in soup.find_all('a', href=True):
            if doc.get_text() == 'View/Open':
                links.append(doc['href'])

        #Recuperando e gravando arquivo PDF
        url = 'http://repositorio.ufpe.br' + links[0]
        pdf = requests.get(url, proxies = proxies)
        filename = tese[1]['PDF_ID'] + '.pdf'
        with open(filename, 'wb') as f:
            f.write(pdf.content)
    except:
        pass
