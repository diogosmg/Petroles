# %% [markdown]
# Script para buscar resumos das teses elaboradas pelos empregados da Petrobras

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import json
import nltk
from nltk.tokenize import word_tokenize
from langdetect import detect
from langdetect import detect_langs
from keras.models import load_model
import gensim
from gensim.models import Word2Vec
import csv
import re
# Out:
# Using TensorFlow backend.
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# Definindo configurações globais de proxy para realizar a extração dentro da rede Petrobras
chave = 'upe2'
pwd = 'fBO61291'
proxy_url = 'http://'+chave+':'+pwd+'@inet-sys.gnet.petrobras.com.br:804/'
proxies = {
  'http' : proxy_url ,
  'https' : proxy_url ,
}

# %% [markdown]
# Inicialmente entraremos no site da BDTD e buscaremos os links de todas as teses de uma determinada intituição.

# %%
#função para coletar os links das tese

def get_links(page):
        
    #preparar a url
    url = ('http://bdtd.ibict.br/vufind/Search/Results?filter%5B%5D=institution%3A%22UFRN%22&type=AllFields&page=' +
           str(page))
    
    #Fazer requisição e parsear o arquivo html
    f = requests.get(url, proxies = proxies).text 
    soup = bs(f, "html.parser")

    #Coletando link para as teses
    links = []
    for doc in soup.find_all('a', href=True):
        if 'title' in doc.get('class', []):
            links.append(doc['href'])
    return links

# %%
#Coletar o link de todas as teses
start_page = 1
n_pages = 633 # Cada página retorna 20 teses

links = []

for p in range(start_page, n_pages):
    link = get_links(p)
    if link != []:
        links = links + link
    else:
        break
    
    if p % 100 == 0:
        print (p*20, ' links capturados, ', p, ' páginas')
        with open('links_ufrn', "w") as output:
            writer = csv.writer(output, lineterminator='\n')
            for val in links:
                writer.writerow([val])
                
with open('links_ufrn', "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in links:
        writer.writerow([val]) 
print (p*20, ' links capturados, ', p, ' páginas')
# Out:
# 2000  links capturados,  100  páginas
# 4000  links capturados,  200  páginas
# 6000  links capturados,  300  páginas
# 8000  links capturados,  400  páginas
# 10000  links capturados,  500  páginas
# 12000  links capturados,  600  páginas
# 12640  links capturados,  632  páginas

# %%
# Abrindo arquivo gravado anteriormente

#links = []
#with open('links_ufrn', 'r') as f:
#    reader = csv.reader(f)
#    for link in reader:
#        links.append(link[0])

# %% [markdown]
# Em seguida vamos recuperar os metadados de cada link coletado anteriormente.

# %%
#função para buscar os metadados das teses no BDTD
def tese_link(link):
    #definir url
    url = 'http://bdtd.ibict.br' + link
    
    #Requisitar html e fazer o parser
    f = requests.get(url, proxies = proxies).text 
    soup = bs(f, "html.parser")

    #Dicionário para armazenar as informações da tese
    tese = {}  
    
    #Adicionar título
    tese['Title'] = soup.find('h3').get_text()
    for doc in soup.find_all('tr'):
        #Identificar atributo
        try:
            atributo = doc.find('th').get_text()
        except:
            pass
        #Verificar se o atributo possui mais de um dado
        for row in doc.find_all('td'):
            #Adicionar o atributo no dicionário
            if row.find('div') == None:
                try:
                    tese[atributo] = doc.find('td').get_text()
                except:
                    pass
            else:
                element = []
                #No dicionário, adicionar todos os dados ao seu respectivo atributo
                for e in doc.find_all('div'):
                    try:
                        sub_e = []
                        for sub_element in e.find_all('a'):
                            element.append(sub_element.get_text()) 
                        #element.append(sub_e)
                    except:
                        pass
                tese[atributo] = element
    
    return(tese)

# %% [markdown]
# Como em alguns casos o resumo português e inglês se misturaram, foi implementado uma função para separar os textos misturados

# %%
# Função para separar resumos português e inglês
def separacao_port_engl(abstract):

    mix_sent = nltk.sent_tokenize(abstract)

    new_mix = []
    for sent in mix_sent:
        position = sent.find('.')
        if position != len(sent)-1:
            sent_1 = sent[:position+1]
            sent_2 = sent[position+1:]
            new_mix.append(sent_1)
            new_mix.append(sent_2)
        else:
            new_mix.append(sent)

    mix_sent = new_mix

    port = []
    engl = []

    for sent in mix_sent:
        try:
            if detect (sent) == 'pt':
                port.append(sent)
            else:
                engl.append (sent)
        except:
            pass

    port = " ".join(port)
    engl = " ".join(engl)

    return(port, engl)

# %% [markdown]
# Até esse momento estamos recuperando as informações de todas as teses de uma determinada instituição. No entanto o objetivo é gravar os metadados e salvar o arquivo apenas das teses relacionadas a O&G. Portanto, vamos carregar os algoritmos de classificação e de vetorização de palavras treinados previamente.

# %%
# Carregando modelo Word2Vec
BDTD_word2vec_50 = Word2Vec.load("..\..\..\Embeddings\BDTD_word2vec_50")
# Carregando modelo keras
model_keras = load_model('..\..\..\model_cnn.h5')
model_keras.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:131: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 400, 50)           9289150
# _________________________________________________________________
# spatial_dropout1d_6 (Spatial (None, 400, 50)           0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 396, 128)          32128
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 198, 128)          0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 198, 128)          0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 194, 128)          82048
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 97, 128)           0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 97, 128)           0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 93, 128)           82048
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 128)               0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               66048
# _________________________________________________________________
# dense_31 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 9,814,591
# Trainable params: 525,441
# Non-trainable params: 9,289,150
# _________________________________________________________________

# %%
# dicionário proveniente do modelo de word embedding para converter palavras em índices
word2index = {}
for index, word in enumerate(BDTD_word2vec_50.wv.index2word):
    word2index[word] = index
    
# Função para converter texto em sequência de índices
def index_pad_text(text, maxlen, word2index):
    maxlen = 400
    new_text = [] 
    
    for word in word_tokenize(text):
        try:
            new_text.append(word2index[word])
        except:
            pass
    # Add the padding for each sentence. Here I am padding with 0
    if len(new_text) > maxlen:
        new_text = new_text[:400]
    else:
        new_text += [0] * (maxlen - len(new_text))

    return np.array(new_text)

maxlen = 400

# %% [markdown]
# Para cada link coletado será fita as seguintes tarefas:
# * verificar se o texto português e inglês estão misturados;
# * transformar o texto em sequência de índices;
# * classificar quanto a relevância ao domínio de O&G;
# * se for relevante, gravar os metadados

# %%
# Dicionário para agrupar os metadados
metadados = {}
# Contadores te links testados e classificados como O&G
n_test = 0
n_pet = 0
# Testando cada link de links
for link in links:
    n_test += 1
    try:
        # Recuperar o metadados de uma tese
        metadado = tese_link(link)
        # Verificar se existe resumo em inglês, separar texto português/inglês e realocar 
        # os textos separados nas respectivas colunas
        if 'Resumo inglês:' not in metadado:
            metadado['Resumo inglês:'] = separacao_port_engl(metadado['Resumo Português:'])[1]
        metadado['Resumo Português:'] = separacao_port_engl(metadado['Resumo Português:'])[0]
        # Colocando o texto em minúscula
        text = metadado['Resumo Português:'].lower()
        # Convertendo as palavras em sequencias de acordo com o modelo word2vec
        text_seq = index_pad_text(text, maxlen, word2index)
        text_seq = text_seq.reshape((1, 400))
        # Usando o algoritmo classificador para prever se a tese é relevante
        pred = model_keras.predict(text_seq)[0]
        #Se a classificação for menor do que 0.2 manter os metadados
        if (pred < 0.2 and len(text) > 100):
            metadado['Classificador'] = pred[0]
            texto_completo = metadado['Download Texto Completo:']
            metadados[texto_completo] = metadado
            n_pet += 1
            # Gravando os resultados em JSON
            metadados_ufrn = pd.DataFrame.from_dict(metadados, orient='index')
            metadados_ufrn.to_json('metadados_ufrn.json', orient = 'index')
            print(n_test, " teses avaliadas e ", n_pet, " teses relacionadas a O&G encontradas.")
    
    except:
        pass
# Out:
# 4  teses avaliadas e  1  teses relacionadas a O&G encontradas.
# 39  teses avaliadas e  2  teses relacionadas a O&G encontradas.
# 40  teses avaliadas e  3  teses relacionadas a O&G encontradas.
# 131  teses avaliadas e  4  teses relacionadas a O&G encontradas.
# 222  teses avaliadas e  5  teses relacionadas a O&G encontradas.
# 250  teses avaliadas e  6  teses relacionadas a O&G encontradas.
# 330  teses avaliadas e  7  teses relacionadas a O&G encontradas.
# 334  teses avaliadas e  8  teses relacionadas a O&G encontradas.
# 346  teses avaliadas e  9  teses relacionadas a O&G encontradas.
# 355  teses avaliadas e  10  teses relacionadas a O&G encontradas.
# 364  teses avaliadas e  11  teses relacionadas a O&G encontradas.
# 370  teses avaliadas e  12  teses relacionadas a O&G encontradas.
# 371  teses avaliadas e  13  teses relacionadas a O&G encontradas.
# 456  teses avaliadas e  14  teses relacionadas a O&G encontradas.
# 457  teses avaliadas e  15  teses relacionadas a O&G encontradas.
# 458  teses avaliadas e  16  teses relacionadas a O&G encontradas.
# 579  teses avaliadas e  17  teses relacionadas a O&G encontradas.
# 591  teses avaliadas e  18  teses relacionadas a O&G encontradas.
# 592  teses avaliadas e  19  teses relacionadas a O&G encontradas.
# 647  teses avaliadas e  20  teses relacionadas a O&G encontradas.
# 648  teses avaliadas e  21  teses relacionadas a O&G encontradas.
# 774  teses avaliadas e  22  teses relacionadas a O&G encontradas.
# 788  teses avaliadas e  23  teses relacionadas a O&G encontradas.
# 839  teses avaliadas e  24  teses relacionadas a O&G encontradas.
# 844  teses avaliadas e  25  teses relacionadas a O&G encontradas.
# 849  teses avaliadas e  26  teses relacionadas a O&G encontradas.
# 852  teses avaliadas e  27  teses relacionadas a O&G encontradas.
# 855  teses avaliadas e  28  teses relacionadas a O&G encontradas.
# 856  teses avaliadas e  29  teses relacionadas a O&G encontradas.
# 885  teses avaliadas e  30  teses relacionadas a O&G encontradas.
# 932  teses avaliadas e  31  teses relacionadas a O&G encontradas.
# 940  teses avaliadas e  32  teses relacionadas a O&G encontradas.
# 945  teses avaliadas e  33  teses relacionadas a O&G encontradas.
# 947  teses avaliadas e  34  teses relacionadas a O&G encontradas.
# 948  teses avaliadas e  35  teses relacionadas a O&G encontradas.
# 949  teses avaliadas e  36  teses relacionadas a O&G encontradas.
# 952  teses avaliadas e  37  teses relacionadas a O&G encontradas.
# 955  teses avaliadas e  38  teses relacionadas a O&G encontradas.
# 959  teses avaliadas e  39  teses relacionadas a O&G encontradas.
# 960  teses avaliadas e  40  teses relacionadas a O&G encontradas.
# 965  teses avaliadas e  41  teses relacionadas a O&G encontradas.
# 967  teses avaliadas e  42  teses relacionadas a O&G encontradas.
# 970  teses avaliadas e  43  teses relacionadas a O&G encontradas.
# 974  teses avaliadas e  44  teses relacionadas a O&G encontradas.
# 980  teses avaliadas e  45  teses relacionadas a O&G encontradas.
# 985  teses avaliadas e  46  teses relacionadas a O&G encontradas.
# 990  teses avaliadas e  47  teses relacionadas a O&G encontradas.
# 996  teses avaliadas e  48  teses relacionadas a O&G encontradas.
# 997  teses avaliadas e  49  teses relacionadas a O&G encontradas.
# 998  teses avaliadas e  50  teses relacionadas a O&G encontradas.
# 1002  teses avaliadas e  51  teses relacionadas a O&G encontradas.
# 1005  teses avaliadas e  52  teses relacionadas a O&G encontradas.
# 1006  teses avaliadas e  53  teses relacionadas a O&G encontradas.
# 1010  teses avaliadas e  54  teses relacionadas a O&G encontradas.
# 1011  teses avaliadas e  55  teses relacionadas a O&G encontradas.
# 1012  teses avaliadas e  56  teses relacionadas a O&G encontradas.
# 1013  teses avaliadas e  57  teses relacionadas a O&G encontradas.
# 1059  teses avaliadas e  58  teses relacionadas a O&G encontradas.
# 1071  teses avaliadas e  59  teses relacionadas a O&G encontradas.
# 1077  teses avaliadas e  60  teses relacionadas a O&G encontradas.
# 1124  teses avaliadas e  61  teses relacionadas a O&G encontradas.
# 1159  teses avaliadas e  62  teses relacionadas a O&G encontradas.
# 1208  teses avaliadas e  63  teses relacionadas a O&G encontradas.
# 1209  teses avaliadas e  64  teses relacionadas a O&G encontradas.
# 1246  teses avaliadas e  65  teses relacionadas a O&G encontradas.
# 1257  teses avaliadas e  66  teses relacionadas a O&G encontradas.
# 1264  teses avaliadas e  67  teses relacionadas a O&G encontradas.
# 1354  teses avaliadas e  68  teses relacionadas a O&G encontradas.
# 1361  teses avaliadas e  69  teses relacionadas a O&G encontradas.
# 1372  teses avaliadas e  70  teses relacionadas a O&G encontradas.
# 1373  teses avaliadas e  71  teses relacionadas a O&G encontradas.
# 1442  teses avaliadas e  72  teses relacionadas a O&G encontradas.
# 1451  teses avaliadas e  73  teses relacionadas a O&G encontradas.
# 1472  teses avaliadas e  74  teses relacionadas a O&G encontradas.
# 1508  teses avaliadas e  75  teses relacionadas a O&G encontradas.
# 1585  teses avaliadas e  76  teses relacionadas a O&G encontradas.
# 1707  teses avaliadas e  77  teses relacionadas a O&G encontradas.
# 1734  teses avaliadas e  78  teses relacionadas a O&G encontradas.
# 1738  teses avaliadas e  79  teses relacionadas a O&G encontradas.
# 1746  teses avaliadas e  80  teses relacionadas a O&G encontradas.
# 1747  teses avaliadas e  81  teses relacionadas a O&G encontradas.
# 1779  teses avaliadas e  82  teses relacionadas a O&G encontradas.
# 1846  teses avaliadas e  83  teses relacionadas a O&G encontradas.
# 1859  teses avaliadas e  84  teses relacionadas a O&G encontradas.
# 1861  teses avaliadas e  85  teses relacionadas a O&G encontradas.
# 1887  teses avaliadas e  86  teses relacionadas a O&G encontradas.
# 1973  teses avaliadas e  87  teses relacionadas a O&G encontradas.
# 2003  teses avaliadas e  88  teses relacionadas a O&G encontradas.
# 2006  teses avaliadas e  89  teses relacionadas a O&G encontradas.
# 2080  teses avaliadas e  90  teses relacionadas a O&G encontradas.
# 2145  teses avaliadas e  91  teses relacionadas a O&G encontradas.
# 2153  teses avaliadas e  92  teses relacionadas a O&G encontradas.
# 2155  teses avaliadas e  93  teses relacionadas a O&G encontradas.
# 2182  teses avaliadas e  94  teses relacionadas a O&G encontradas.
# 2191  teses avaliadas e  95  teses relacionadas a O&G encontradas.
# 2225  teses avaliadas e  96  teses relacionadas a O&G encontradas.
# 2265  teses avaliadas e  97  teses relacionadas a O&G encontradas.
# 2283  teses avaliadas e  98  teses relacionadas a O&G encontradas.
# 2300  teses avaliadas e  99  teses relacionadas a O&G encontradas.
# 2370  teses avaliadas e  100  teses relacionadas a O&G encontradas.
# 2393  teses avaliadas e  101  teses relacionadas a O&G encontradas.
# 2395  teses avaliadas e  102  teses relacionadas a O&G encontradas.
# 2404  teses avaliadas e  103  teses relacionadas a O&G encontradas.
# 2411  teses avaliadas e  104  teses relacionadas a O&G encontradas.
# 2427  teses avaliadas e  105  teses relacionadas a O&G encontradas.
# 2432  teses avaliadas e  106  teses relacionadas a O&G encontradas.
# 2486  teses avaliadas e  107  teses relacionadas a O&G encontradas.
# 2599  teses avaliadas e  108  teses relacionadas a O&G encontradas.
# 2605  teses avaliadas e  109  teses relacionadas a O&G encontradas.
# 2606  teses avaliadas e  110  teses relacionadas a O&G encontradas.
# 2625  teses avaliadas e  111  teses relacionadas a O&G encontradas.
# 2642  teses avaliadas e  112  teses relacionadas a O&G encontradas.
# 2669  teses avaliadas e  113  teses relacionadas a O&G encontradas.
# 2683  teses avaliadas e  114  teses relacionadas a O&G encontradas.
# 2744  teses avaliadas e  115  teses relacionadas a O&G encontradas.
# 2750  teses avaliadas e  116  teses relacionadas a O&G encontradas.
# 2830  teses avaliadas e  117  teses relacionadas a O&G encontradas.
# 2839  teses avaliadas e  118  teses relacionadas a O&G encontradas.
# 2841  teses avaliadas e  119  teses relacionadas a O&G encontradas.
# 2849  teses avaliadas e  120  teses relacionadas a O&G encontradas.
# 2865  teses avaliadas e  121  teses relacionadas a O&G encontradas.
# 2922  teses avaliadas e  122  teses relacionadas a O&G encontradas.
# 2931  teses avaliadas e  123  teses relacionadas a O&G encontradas.
# 2932  teses avaliadas e  124  teses relacionadas a O&G encontradas.
# 2933  teses avaliadas e  125  teses relacionadas a O&G encontradas.
# 2938  teses avaliadas e  126  teses relacionadas a O&G encontradas.
# 3015  teses avaliadas e  127  teses relacionadas a O&G encontradas.
# 3052  teses avaliadas e  128  teses relacionadas a O&G encontradas.
# 3058  teses avaliadas e  129  teses relacionadas a O&G encontradas.
# 3078  teses avaliadas e  130  teses relacionadas a O&G encontradas.
# 3079  teses avaliadas e  131  teses relacionadas a O&G encontradas.
# 3189  teses avaliadas e  132  teses relacionadas a O&G encontradas.
# 3190  teses avaliadas e  133  teses relacionadas a O&G encontradas.
# 3247  teses avaliadas e  134  teses relacionadas a O&G encontradas.
# 3249  teses avaliadas e  135  teses relacionadas a O&G encontradas.
# 3261  teses avaliadas e  136  teses relacionadas a O&G encontradas.
# 3285  teses avaliadas e  137  teses relacionadas a O&G encontradas.
# 3348  teses avaliadas e  138  teses relacionadas a O&G encontradas.
# 3353  teses avaliadas e  139  teses relacionadas a O&G encontradas.
# 3370  teses avaliadas e  140  teses relacionadas a O&G encontradas.
# 3416  teses avaliadas e  141  teses relacionadas a O&G encontradas.
# 3446  teses avaliadas e  142  teses relacionadas a O&G encontradas.
# 3491  teses avaliadas e  143  teses relacionadas a O&G encontradas.
# 3547  teses avaliadas e  144  teses relacionadas a O&G encontradas.
# 3564  teses avaliadas e  145  teses relacionadas a O&G encontradas.
# 3571  teses avaliadas e  146  teses relacionadas a O&G encontradas.
# 3590  teses avaliadas e  147  teses relacionadas a O&G encontradas.
# 3607  teses avaliadas e  148  teses relacionadas a O&G encontradas.
# 3610  teses avaliadas e  149  teses relacionadas a O&G encontradas.
# 3619  teses avaliadas e  150  teses relacionadas a O&G encontradas.
# 3645  teses avaliadas e  151  teses relacionadas a O&G encontradas.
# 3669  teses avaliadas e  152  teses relacionadas a O&G encontradas.
# 3676  teses avaliadas e  153  teses relacionadas a O&G encontradas.
# 3679  teses avaliadas e  154  teses relacionadas a O&G encontradas.
# 3680  teses avaliadas e  155  teses relacionadas a O&G encontradas.
# 3684  teses avaliadas e  156  teses relacionadas a O&G encontradas.
# 3694  teses avaliadas e  157  teses relacionadas a O&G encontradas.
# 3696  teses avaliadas e  158  teses relacionadas a O&G encontradas.
# 3716  teses avaliadas e  159  teses relacionadas a O&G encontradas.
# 3717  teses avaliadas e  160  teses relacionadas a O&G encontradas.
# 3733  teses avaliadas e  161  teses relacionadas a O&G encontradas.
# 3739  teses avaliadas e  162  teses relacionadas a O&G encontradas.
# 3769  teses avaliadas e  163  teses relacionadas a O&G encontradas.
# 3811  teses avaliadas e  164  teses relacionadas a O&G encontradas.
# 3813  teses avaliadas e  165  teses relacionadas a O&G encontradas.
# 3846  teses avaliadas e  166  teses relacionadas a O&G encontradas.
# 3878  teses avaliadas e  167  teses relacionadas a O&G encontradas.
# 3892  teses avaliadas e  168  teses relacionadas a O&G encontradas.
# 3949  teses avaliadas e  169  teses relacionadas a O&G encontradas.
# 3950  teses avaliadas e  170  teses relacionadas a O&G encontradas.
# 3971  teses avaliadas e  171  teses relacionadas a O&G encontradas.
# 3973  teses avaliadas e  172  teses relacionadas a O&G encontradas.
# 3989  teses avaliadas e  173  teses relacionadas a O&G encontradas.
# 4078  teses avaliadas e  174  teses relacionadas a O&G encontradas.
# 4092  teses avaliadas e  175  teses relacionadas a O&G encontradas.
# 4093  teses avaliadas e  176  teses relacionadas a O&G encontradas.
# 4096  teses avaliadas e  177  teses relacionadas a O&G encontradas.
# 4116  teses avaliadas e  178  teses relacionadas a O&G encontradas.
# 4147  teses avaliadas e  179  teses relacionadas a O&G encontradas.
# 4153  teses avaliadas e  180  teses relacionadas a O&G encontradas.
# 4160  teses avaliadas e  181  teses relacionadas a O&G encontradas.
# 4169  teses avaliadas e  182  teses relacionadas a O&G encontradas.
# 4318  teses avaliadas e  183  teses relacionadas a O&G encontradas.
# 4322  teses avaliadas e  184  teses relacionadas a O&G encontradas.
# 4369  teses avaliadas e  185  teses relacionadas a O&G encontradas.
# 4404  teses avaliadas e  186  teses relacionadas a O&G encontradas.
# 4423  teses avaliadas e  187  teses relacionadas a O&G encontradas.
# 4430  teses avaliadas e  188  teses relacionadas a O&G encontradas.
# 4538  teses avaliadas e  189  teses relacionadas a O&G encontradas.
# 4553  teses avaliadas e  190  teses relacionadas a O&G encontradas.
# 4556  teses avaliadas e  191  teses relacionadas a O&G encontradas.
# 4669  teses avaliadas e  192  teses relacionadas a O&G encontradas.
# 4687  teses avaliadas e  193  teses relacionadas a O&G encontradas.
# 4689  teses avaliadas e  194  teses relacionadas a O&G encontradas.
# 4701  teses avaliadas e  195  teses relacionadas a O&G encontradas.
# 4715  teses avaliadas e  196  teses relacionadas a O&G encontradas.
# 4719  teses avaliadas e  197  teses relacionadas a O&G encontradas.
# 4759  teses avaliadas e  198  teses relacionadas a O&G encontradas.
# 4783  teses avaliadas e  199  teses relacionadas a O&G encontradas.
# 4807  teses avaliadas e  200  teses relacionadas a O&G encontradas.
# 4809  teses avaliadas e  201  teses relacionadas a O&G encontradas.
# 4810  teses avaliadas e  202  teses relacionadas a O&G encontradas.
# 4811  teses avaliadas e  203  teses relacionadas a O&G encontradas.
# 4885  teses avaliadas e  204  teses relacionadas a O&G encontradas.
# 4907  teses avaliadas e  205  teses relacionadas a O&G encontradas.
# 4924  teses avaliadas e  206  teses relacionadas a O&G encontradas.
# 5011  teses avaliadas e  207  teses relacionadas a O&G encontradas.
# 5012  teses avaliadas e  208  teses relacionadas a O&G encontradas.
# 5013  teses avaliadas e  209  teses relacionadas a O&G encontradas.
# 5068  teses avaliadas e  210  teses relacionadas a O&G encontradas.
# 5090  teses avaliadas e  211  teses relacionadas a O&G encontradas.
# 5091  teses avaliadas e  212  teses relacionadas a O&G encontradas.
# 5102  teses avaliadas e  213  teses relacionadas a O&G encontradas.
# 5103  teses avaliadas e  214  teses relacionadas a O&G encontradas.
# 5493  teses avaliadas e  215  teses relacionadas a O&G encontradas.
# 5503  teses avaliadas e  216  teses relacionadas a O&G encontradas.
# 5509  teses avaliadas e  217  teses relacionadas a O&G encontradas.
# 5513  teses avaliadas e  218  teses relacionadas a O&G encontradas.
# 5514  teses avaliadas e  219  teses relacionadas a O&G encontradas.
# 5516  teses avaliadas e  220  teses relacionadas a O&G encontradas.
# 5519  teses avaliadas e  221  teses relacionadas a O&G encontradas.
# 5520  teses avaliadas e  222  teses relacionadas a O&G encontradas.
# 5521  teses avaliadas e  223  teses relacionadas a O&G encontradas.
# 5523  teses avaliadas e  224  teses relacionadas a O&G encontradas.
# 5529  teses avaliadas e  225  teses relacionadas a O&G encontradas.
# 5531  teses avaliadas e  226  teses relacionadas a O&G encontradas.
# 5538  teses avaliadas e  227  teses relacionadas a O&G encontradas.
# 5540  teses avaliadas e  228  teses relacionadas a O&G encontradas.
# 5548  teses avaliadas e  229  teses relacionadas a O&G encontradas.
# 5561  teses avaliadas e  230  teses relacionadas a O&G encontradas.
# 5568  teses avaliadas e  231  teses relacionadas a O&G encontradas.
# 5581  teses avaliadas e  232  teses relacionadas a O&G encontradas.
# 5586  teses avaliadas e  233  teses relacionadas a O&G encontradas.
# 5587  teses avaliadas e  234  teses relacionadas a O&G encontradas.
# 5598  teses avaliadas e  235  teses relacionadas a O&G encontradas.
# 5599  teses avaliadas e  236  teses relacionadas a O&G encontradas.
# 5607  teses avaliadas e  237  teses relacionadas a O&G encontradas.
# 5609  teses avaliadas e  238  teses relacionadas a O&G encontradas.
# 5610  teses avaliadas e  239  teses relacionadas a O&G encontradas.
# 5619  teses avaliadas e  240  teses relacionadas a O&G encontradas.
# 5628  teses avaliadas e  241  teses relacionadas a O&G encontradas.
# 5630  teses avaliadas e  242  teses relacionadas a O&G encontradas.
# 5643  teses avaliadas e  243  teses relacionadas a O&G encontradas.
# 5662  teses avaliadas e  244  teses relacionadas a O&G encontradas.
# 5664  teses avaliadas e  245  teses relacionadas a O&G encontradas.
# 5665  teses avaliadas e  246  teses relacionadas a O&G encontradas.
# 5672  teses avaliadas e  247  teses relacionadas a O&G encontradas.
# 5674  teses avaliadas e  248  teses relacionadas a O&G encontradas.
# 5675  teses avaliadas e  249  teses relacionadas a O&G encontradas.
# 5680  teses avaliadas e  250  teses relacionadas a O&G encontradas.
# 5681  teses avaliadas e  251  teses relacionadas a O&G encontradas.
# 5683  teses avaliadas e  252  teses relacionadas a O&G encontradas.
# 5686  teses avaliadas e  253  teses relacionadas a O&G encontradas.
# 5689  teses avaliadas e  254  teses relacionadas a O&G encontradas.
# 5693  teses avaliadas e  255  teses relacionadas a O&G encontradas.
# 5694  teses avaliadas e  256  teses relacionadas a O&G encontradas.
# 5697  teses avaliadas e  257  teses relacionadas a O&G encontradas.
# 5698  teses avaliadas e  258  teses relacionadas a O&G encontradas.
# 5699  teses avaliadas e  259  teses relacionadas a O&G encontradas.
# 5701  teses avaliadas e  260  teses relacionadas a O&G encontradas.
# 5843  teses avaliadas e  261  teses relacionadas a O&G encontradas.
# 5858  teses avaliadas e  262  teses relacionadas a O&G encontradas.
# 5895  teses avaliadas e  263  teses relacionadas a O&G encontradas.
# 5906  teses avaliadas e  264  teses relacionadas a O&G encontradas.
# 5940  teses avaliadas e  265  teses relacionadas a O&G encontradas.
# 5952  teses avaliadas e  266  teses relacionadas a O&G encontradas.
# 5953  teses avaliadas e  267  teses relacionadas a O&G encontradas.
# 5960  teses avaliadas e  268  teses relacionadas a O&G encontradas.
# 5991  teses avaliadas e  269  teses relacionadas a O&G encontradas.
# 6017  teses avaliadas e  270  teses relacionadas a O&G encontradas.
# 6186  teses avaliadas e  271  teses relacionadas a O&G encontradas.
# 6219  teses avaliadas e  272  teses relacionadas a O&G encontradas.
# 6220  teses avaliadas e  273  teses relacionadas a O&G encontradas.
# 6223  teses avaliadas e  274  teses relacionadas a O&G encontradas.
# 6226  teses avaliadas e  275  teses relacionadas a O&G encontradas.
# 6230  teses avaliadas e  276  teses relacionadas a O&G encontradas.
# 6237  teses avaliadas e  277  teses relacionadas a O&G encontradas.
# 6242  teses avaliadas e  278  teses relacionadas a O&G encontradas.
# 6269  teses avaliadas e  279  teses relacionadas a O&G encontradas.
# 6270  teses avaliadas e  280  teses relacionadas a O&G encontradas.
# 6271  teses avaliadas e  281  teses relacionadas a O&G encontradas.
# 6290  teses avaliadas e  282  teses relacionadas a O&G encontradas.
# 6291  teses avaliadas e  283  teses relacionadas a O&G encontradas.
# 6301  teses avaliadas e  284  teses relacionadas a O&G encontradas.
# 6306  teses avaliadas e  285  teses relacionadas a O&G encontradas.
# 6365  teses avaliadas e  286  teses relacionadas a O&G encontradas.
# 6407  teses avaliadas e  287  teses relacionadas a O&G encontradas.
# 6409  teses avaliadas e  288  teses relacionadas a O&G encontradas.
# 6434  teses avaliadas e  289  teses relacionadas a O&G encontradas.
# 6442  teses avaliadas e  290  teses relacionadas a O&G encontradas.
# 6443  teses avaliadas e  291  teses relacionadas a O&G encontradas.
# 6454  teses avaliadas e  292  teses relacionadas a O&G encontradas.
# 6455  teses avaliadas e  293  teses relacionadas a O&G encontradas.
# 6467  teses avaliadas e  294  teses relacionadas a O&G encontradas.
# 6503  teses avaliadas e  295  teses relacionadas a O&G encontradas.
# 6560  teses avaliadas e  296  teses relacionadas a O&G encontradas.
# 6587  teses avaliadas e  297  teses relacionadas a O&G encontradas.
# 6603  teses avaliadas e  298  teses relacionadas a O&G encontradas.
# 6615  teses avaliadas e  299  teses relacionadas a O&G encontradas.
# 6617  teses avaliadas e  300  teses relacionadas a O&G encontradas.
# 6652  teses avaliadas e  301  teses relacionadas a O&G encontradas.
# 6663  teses avaliadas e  302  teses relacionadas a O&G encontradas.
# 6676  teses avaliadas e  303  teses relacionadas a O&G encontradas.
# 6679  teses avaliadas e  304  teses relacionadas a O&G encontradas.
# 6698  teses avaliadas e  305  teses relacionadas a O&G encontradas.
# 6699  teses avaliadas e  306  teses relacionadas a O&G encontradas.
# 6704  teses avaliadas e  307  teses relacionadas a O&G encontradas.
# 6720  teses avaliadas e  308  teses relacionadas a O&G encontradas.
# 6770  teses avaliadas e  309  teses relacionadas a O&G encontradas.
# 6806  teses avaliadas e  310  teses relacionadas a O&G encontradas.
# 6827  teses avaliadas e  311  teses relacionadas a O&G encontradas.
# 6887  teses avaliadas e  312  teses relacionadas a O&G encontradas.
# 6923  teses avaliadas e  313  teses relacionadas a O&G encontradas.
# 6934  teses avaliadas e  314  teses relacionadas a O&G encontradas.
# 6939  teses avaliadas e  315  teses relacionadas a O&G encontradas.
# 6954  teses avaliadas e  316  teses relacionadas a O&G encontradas.
# 6997  teses avaliadas e  317  teses relacionadas a O&G encontradas.
# 7037  teses avaliadas e  318  teses relacionadas a O&G encontradas.
# 7065  teses avaliadas e  319  teses relacionadas a O&G encontradas.
# 7108  teses avaliadas e  320  teses relacionadas a O&G encontradas.
# 7114  teses avaliadas e  321  teses relacionadas a O&G encontradas.
# 7117  teses avaliadas e  322  teses relacionadas a O&G encontradas.
# 7120  teses avaliadas e  323  teses relacionadas a O&G encontradas.
# 7132  teses avaliadas e  324  teses relacionadas a O&G encontradas.
# 7172  teses avaliadas e  325  teses relacionadas a O&G encontradas.
# 7175  teses avaliadas e  326  teses relacionadas a O&G encontradas.
# 7209  teses avaliadas e  327  teses relacionadas a O&G encontradas.
# 7210  teses avaliadas e  328  teses relacionadas a O&G encontradas.
# 7269  teses avaliadas e  329  teses relacionadas a O&G encontradas.
# 7277  teses avaliadas e  330  teses relacionadas a O&G encontradas.
# 7281  teses avaliadas e  331  teses relacionadas a O&G encontradas.
# 7282  teses avaliadas e  332  teses relacionadas a O&G encontradas.
# 7287  teses avaliadas e  333  teses relacionadas a O&G encontradas.
# 7309  teses avaliadas e  334  teses relacionadas a O&G encontradas.
# 7358  teses avaliadas e  335  teses relacionadas a O&G encontradas.
# 7373  teses avaliadas e  336  teses relacionadas a O&G encontradas.
# 7391  teses avaliadas e  337  teses relacionadas a O&G encontradas.
# 7410  teses avaliadas e  338  teses relacionadas a O&G encontradas.
# 7414  teses avaliadas e  339  teses relacionadas a O&G encontradas.
# 7449  teses avaliadas e  340  teses relacionadas a O&G encontradas.
# 7511  teses avaliadas e  341  teses relacionadas a O&G encontradas.
# 7551  teses avaliadas e  342  teses relacionadas a O&G encontradas.
# 7594  teses avaliadas e  343  teses relacionadas a O&G encontradas.
# 7603  teses avaliadas e  344  teses relacionadas a O&G encontradas.
# 7612  teses avaliadas e  345  teses relacionadas a O&G encontradas.
# 7623  teses avaliadas e  346  teses relacionadas a O&G encontradas.
# 7643  teses avaliadas e  347  teses relacionadas a O&G encontradas.
# 7646  teses avaliadas e  348  teses relacionadas a O&G encontradas.
# 7678  teses avaliadas e  349  teses relacionadas a O&G encontradas.
# 7680  teses avaliadas e  350  teses relacionadas a O&G encontradas.
# 7682  teses avaliadas e  351  teses relacionadas a O&G encontradas.
# 7683  teses avaliadas e  352  teses relacionadas a O&G encontradas.
# 7713  teses avaliadas e  353  teses relacionadas a O&G encontradas.
# 7725  teses avaliadas e  354  teses relacionadas a O&G encontradas.
# 8481  teses avaliadas e  355  teses relacionadas a O&G encontradas.
# 8523  teses avaliadas e  356  teses relacionadas a O&G encontradas.
# 8526  teses avaliadas e  357  teses relacionadas a O&G encontradas.
# 8532  teses avaliadas e  358  teses relacionadas a O&G encontradas.
# 8539  teses avaliadas e  359  teses relacionadas a O&G encontradas.
# 8545  teses avaliadas e  360  teses relacionadas a O&G encontradas.
# 8547  teses avaliadas e  361  teses relacionadas a O&G encontradas.
# 8549  teses avaliadas e  362  teses relacionadas a O&G encontradas.
# 8551  teses avaliadas e  363  teses relacionadas a O&G encontradas.
# 8552  teses avaliadas e  364  teses relacionadas a O&G encontradas.
# 8553  teses avaliadas e  365  teses relacionadas a O&G encontradas.
# 8558  teses avaliadas e  366  teses relacionadas a O&G encontradas.
# 8577  teses avaliadas e  367  teses relacionadas a O&G encontradas.
# 8590  teses avaliadas e  368  teses relacionadas a O&G encontradas.
# 8606  teses avaliadas e  369  teses relacionadas a O&G encontradas.
# 8648  teses avaliadas e  370  teses relacionadas a O&G encontradas.
# 8699  teses avaliadas e  371  teses relacionadas a O&G encontradas.
# 8700  teses avaliadas e  372  teses relacionadas a O&G encontradas.
# 8708  teses avaliadas e  373  teses relacionadas a O&G encontradas.
# 8714  teses avaliadas e  374  teses relacionadas a O&G encontradas.
# 8735  teses avaliadas e  375  teses relacionadas a O&G encontradas.
# 8982  teses avaliadas e  376  teses relacionadas a O&G encontradas.
# 8983  teses avaliadas e  377  teses relacionadas a O&G encontradas.
# 8984  teses avaliadas e  378  teses relacionadas a O&G encontradas.
# 8992  teses avaliadas e  379  teses relacionadas a O&G encontradas.
# 8994  teses avaliadas e  380  teses relacionadas a O&G encontradas.
# 8999  teses avaliadas e  381  teses relacionadas a O&G encontradas.
# 9002  teses avaliadas e  382  teses relacionadas a O&G encontradas.
# 9005  teses avaliadas e  383  teses relacionadas a O&G encontradas.
# 9006  teses avaliadas e  384  teses relacionadas a O&G encontradas.
# 9008  teses avaliadas e  385  teses relacionadas a O&G encontradas.
# 9009  teses avaliadas e  386  teses relacionadas a O&G encontradas.
# 9012  teses avaliadas e  387  teses relacionadas a O&G encontradas.
# 9013  teses avaliadas e  388  teses relacionadas a O&G encontradas.
# 9017  teses avaliadas e  389  teses relacionadas a O&G encontradas.
# 9018  teses avaliadas e  390  teses relacionadas a O&G encontradas.
# 9024  teses avaliadas e  391  teses relacionadas a O&G encontradas.
# 9027  teses avaliadas e  392  teses relacionadas a O&G encontradas.
# 9028  teses avaliadas e  393  teses relacionadas a O&G encontradas.
# 9030  teses avaliadas e  394  teses relacionadas a O&G encontradas.
# 9035  teses avaliadas e  395  teses relacionadas a O&G encontradas.
# 9036  teses avaliadas e  396  teses relacionadas a O&G encontradas.
# 9037  teses avaliadas e  397  teses relacionadas a O&G encontradas.
# 9043  teses avaliadas e  398  teses relacionadas a O&G encontradas.
# 9044  teses avaliadas e  399  teses relacionadas a O&G encontradas.
# 9045  teses avaliadas e  400  teses relacionadas a O&G encontradas.
# 9046  teses avaliadas e  401  teses relacionadas a O&G encontradas.
# 9050  teses avaliadas e  402  teses relacionadas a O&G encontradas.
# 9060  teses avaliadas e  403  teses relacionadas a O&G encontradas.
# 9061  teses avaliadas e  404  teses relacionadas a O&G encontradas.
# 9063  teses avaliadas e  405  teses relacionadas a O&G encontradas.
# 9067  teses avaliadas e  406  teses relacionadas a O&G encontradas.
# 9070  teses avaliadas e  407  teses relacionadas a O&G encontradas.
# 9073  teses avaliadas e  408  teses relacionadas a O&G encontradas.
# 9081  teses avaliadas e  409  teses relacionadas a O&G encontradas.
# 9082  teses avaliadas e  410  teses relacionadas a O&G encontradas.
# 9085  teses avaliadas e  411  teses relacionadas a O&G encontradas.
# 9087  teses avaliadas e  412  teses relacionadas a O&G encontradas.
# 9092  teses avaliadas e  413  teses relacionadas a O&G encontradas.
# 9099  teses avaliadas e  414  teses relacionadas a O&G encontradas.
# 9106  teses avaliadas e  415  teses relacionadas a O&G encontradas.
# 9108  teses avaliadas e  416  teses relacionadas a O&G encontradas.
# 9112  teses avaliadas e  417  teses relacionadas a O&G encontradas.
# 9118  teses avaliadas e  418  teses relacionadas a O&G encontradas.
# 9123  teses avaliadas e  419  teses relacionadas a O&G encontradas.
# 9126  teses avaliadas e  420  teses relacionadas a O&G encontradas.
# 9127  teses avaliadas e  421  teses relacionadas a O&G encontradas.
# 9129  teses avaliadas e  422  teses relacionadas a O&G encontradas.
# 9133  teses avaliadas e  423  teses relacionadas a O&G encontradas.
# 9134  teses avaliadas e  424  teses relacionadas a O&G encontradas.
# 9139  teses avaliadas e  425  teses relacionadas a O&G encontradas.
# 9140  teses avaliadas e  426  teses relacionadas a O&G encontradas.
# 9142  teses avaliadas e  427  teses relacionadas a O&G encontradas.
# 9146  teses avaliadas e  428  teses relacionadas a O&G encontradas.
# 9149  teses avaliadas e  429  teses relacionadas a O&G encontradas.
# 9150  teses avaliadas e  430  teses relacionadas a O&G encontradas.
# 9151  teses avaliadas e  431  teses relacionadas a O&G encontradas.
# 9155  teses avaliadas e  432  teses relacionadas a O&G encontradas.
# 9157  teses avaliadas e  433  teses relacionadas a O&G encontradas.
# 9164  teses avaliadas e  434  teses relacionadas a O&G encontradas.
# 9167  teses avaliadas e  435  teses relacionadas a O&G encontradas.
# 9171  teses avaliadas e  436  teses relacionadas a O&G encontradas.
# 9173  teses avaliadas e  437  teses relacionadas a O&G encontradas.
# 9175  teses avaliadas e  438  teses relacionadas a O&G encontradas.
# 9176  teses avaliadas e  439  teses relacionadas a O&G encontradas.
# 9177  teses avaliadas e  440  teses relacionadas a O&G encontradas.
# 9178  teses avaliadas e  441  teses relacionadas a O&G encontradas.
# 9180  teses avaliadas e  442  teses relacionadas a O&G encontradas.
# 9181  teses avaliadas e  443  teses relacionadas a O&G encontradas.
# 9183  teses avaliadas e  444  teses relacionadas a O&G encontradas.
# 9186  teses avaliadas e  445  teses relacionadas a O&G encontradas.
# 9187  teses avaliadas e  446  teses relacionadas a O&G encontradas.
# 9188  teses avaliadas e  447  teses relacionadas a O&G encontradas.
# 9189  teses avaliadas e  448  teses relacionadas a O&G encontradas.
# 9191  teses avaliadas e  449  teses relacionadas a O&G encontradas.
# 9195  teses avaliadas e  450  teses relacionadas a O&G encontradas.
# 9201  teses avaliadas e  451  teses relacionadas a O&G encontradas.
# 9212  teses avaliadas e  452  teses relacionadas a O&G encontradas.
# 9272  teses avaliadas e  453  teses relacionadas a O&G encontradas.
# 9792  teses avaliadas e  454  teses relacionadas a O&G encontradas.
# 9793  teses avaliadas e  455  teses relacionadas a O&G encontradas.
# 9805  teses avaliadas e  456  teses relacionadas a O&G encontradas.
# 10081  teses avaliadas e  457  teses relacionadas a O&G encontradas.
# 10155  teses avaliadas e  458  teses relacionadas a O&G encontradas.
# 10162  teses avaliadas e  459  teses relacionadas a O&G encontradas.
# 10728  teses avaliadas e  460  teses relacionadas a O&G encontradas.
# 10737  teses avaliadas e  461  teses relacionadas a O&G encontradas.
# 10763  teses avaliadas e  462  teses relacionadas a O&G encontradas.
# 10768  teses avaliadas e  463  teses relacionadas a O&G encontradas.
# 10810  teses avaliadas e  464  teses relacionadas a O&G encontradas.
# 10843  teses avaliadas e  465  teses relacionadas a O&G encontradas.
# 10885  teses avaliadas e  466  teses relacionadas a O&G encontradas.
# 10890  teses avaliadas e  467  teses relacionadas a O&G encontradas.
# 10961  teses avaliadas e  468  teses relacionadas a O&G encontradas.
# 10963  teses avaliadas e  469  teses relacionadas a O&G encontradas.
# 10979  teses avaliadas e  470  teses relacionadas a O&G encontradas.
# 11016  teses avaliadas e  471  teses relacionadas a O&G encontradas.
# 11020  teses avaliadas e  472  teses relacionadas a O&G encontradas.
# 11022  teses avaliadas e  473  teses relacionadas a O&G encontradas.
# 11028  teses avaliadas e  474  teses relacionadas a O&G encontradas.
# 11062  teses avaliadas e  475  teses relacionadas a O&G encontradas.
# 11091  teses avaliadas e  476  teses relacionadas a O&G encontradas.
# 11113  teses avaliadas e  477  teses relacionadas a O&G encontradas.
# 11118  teses avaliadas e  478  teses relacionadas a O&G encontradas.
# 11120  teses avaliadas e  479  teses relacionadas a O&G encontradas.
# 11146  teses avaliadas e  480  teses relacionadas a O&G encontradas.
# 11154  teses avaliadas e  481  teses relacionadas a O&G encontradas.
# 11155  teses avaliadas e  482  teses relacionadas a O&G encontradas.
# 11159  teses avaliadas e  483  teses relacionadas a O&G encontradas.
# 11160  teses avaliadas e  484  teses relacionadas a O&G encontradas.
# 11167  teses avaliadas e  485  teses relacionadas a O&G encontradas.
# 11172  teses avaliadas e  486  teses relacionadas a O&G encontradas.
# 11208  teses avaliadas e  487  teses relacionadas a O&G encontradas.
# 11221  teses avaliadas e  488  teses relacionadas a O&G encontradas.
# 11223  teses avaliadas e  489  teses relacionadas a O&G encontradas.
# 11246  teses avaliadas e  490  teses relacionadas a O&G encontradas.
# 11247  teses avaliadas e  491  teses relacionadas a O&G encontradas.
# 11262  teses avaliadas e  492  teses relacionadas a O&G encontradas.
# 11286  teses avaliadas e  493  teses relacionadas a O&G encontradas.
# 11292  teses avaliadas e  494  teses relacionadas a O&G encontradas.
# 11306  teses avaliadas e  495  teses relacionadas a O&G encontradas.
# 11321  teses avaliadas e  496  teses relacionadas a O&G encontradas.
# 11322  teses avaliadas e  497  teses relacionadas a O&G encontradas.
# 11327  teses avaliadas e  498  teses relacionadas a O&G encontradas.
# 11332  teses avaliadas e  499  teses relacionadas a O&G encontradas.
# 11351  teses avaliadas e  500  teses relacionadas a O&G encontradas.
# 11356  teses avaliadas e  501  teses relacionadas a O&G encontradas.
# 11357  teses avaliadas e  502  teses relacionadas a O&G encontradas.
# 11374  teses avaliadas e  503  teses relacionadas a O&G encontradas.
# 11380  teses avaliadas e  504  teses relacionadas a O&G encontradas.
# 11383  teses avaliadas e  505  teses relacionadas a O&G encontradas.
# 11408  teses avaliadas e  506  teses relacionadas a O&G encontradas.
# 11412  teses avaliadas e  507  teses relacionadas a O&G encontradas.
# 11420  teses avaliadas e  508  teses relacionadas a O&G encontradas.
# 11435  teses avaliadas e  509  teses relacionadas a O&G encontradas.
# 11441  teses avaliadas e  510  teses relacionadas a O&G encontradas.
# 11447  teses avaliadas e  511  teses relacionadas a O&G encontradas.
# 11451  teses avaliadas e  512  teses relacionadas a O&G encontradas.
# 11453  teses avaliadas e  513  teses relacionadas a O&G encontradas.
# 11464  teses avaliadas e  514  teses relacionadas a O&G encontradas.
# 11491  teses avaliadas e  515  teses relacionadas a O&G encontradas.
# 11496  teses avaliadas e  516  teses relacionadas a O&G encontradas.
# 11519  teses avaliadas e  517  teses relacionadas a O&G encontradas.
# 11540  teses avaliadas e  518  teses relacionadas a O&G encontradas.
# 11836  teses avaliadas e  519  teses relacionadas a O&G encontradas.
# 11899  teses avaliadas e  520  teses relacionadas a O&G encontradas.
# 12024  teses avaliadas e  521  teses relacionadas a O&G encontradas.
# 12071  teses avaliadas e  522  teses relacionadas a O&G encontradas.
# 12074  teses avaliadas e  523  teses relacionadas a O&G encontradas.
# 12099  teses avaliadas e  524  teses relacionadas a O&G encontradas.
# 12100  teses avaliadas e  525  teses relacionadas a O&G encontradas.
# 12108  teses avaliadas e  526  teses relacionadas a O&G encontradas.
# 12109  teses avaliadas e  527  teses relacionadas a O&G encontradas.
# 12111  teses avaliadas e  528  teses relacionadas a O&G encontradas.
# 12116  teses avaliadas e  529  teses relacionadas a O&G encontradas.
# 12118  teses avaliadas e  530  teses relacionadas a O&G encontradas.
# 12123  teses avaliadas e  531  teses relacionadas a O&G encontradas.
# 12125  teses avaliadas e  532  teses relacionadas a O&G encontradas.
# 12136  teses avaliadas e  533  teses relacionadas a O&G encontradas.
# 12139  teses avaliadas e  534  teses relacionadas a O&G encontradas.
# 12144  teses avaliadas e  535  teses relacionadas a O&G encontradas.
# 12145  teses avaliadas e  536  teses relacionadas a O&G encontradas.
# 12152  teses avaliadas e  537  teses relacionadas a O&G encontradas.
# 12158  teses avaliadas e  538  teses relacionadas a O&G encontradas.
# 12167  teses avaliadas e  539  teses relacionadas a O&G encontradas.
# 12171  teses avaliadas e  540  teses relacionadas a O&G encontradas.
# 12181  teses avaliadas e  541  teses relacionadas a O&G encontradas.
# 12182  teses avaliadas e  542  teses relacionadas a O&G encontradas.
# 12187  teses avaliadas e  543  teses relacionadas a O&G encontradas.
# 12202  teses avaliadas e  544  teses relacionadas a O&G encontradas.
# 12206  teses avaliadas e  545  teses relacionadas a O&G encontradas.
# 12207  teses avaliadas e  546  teses relacionadas a O&G encontradas.
# 12216  teses avaliadas e  547  teses relacionadas a O&G encontradas.
# 12218  teses avaliadas e  548  teses relacionadas a O&G encontradas.
# 12219  teses avaliadas e  549  teses relacionadas a O&G encontradas.
# 12231  teses avaliadas e  550  teses relacionadas a O&G encontradas.
# 12233  teses avaliadas e  551  teses relacionadas a O&G encontradas.
# 12254  teses avaliadas e  552  teses relacionadas a O&G encontradas.
# 12271  teses avaliadas e  553  teses relacionadas a O&G encontradas.
# 12274  teses avaliadas e  554  teses relacionadas a O&G encontradas.
# 12277  teses avaliadas e  555  teses relacionadas a O&G encontradas.
# 12278  teses avaliadas e  556  teses relacionadas a O&G encontradas.
# 12286  teses avaliadas e  557  teses relacionadas a O&G encontradas.
# 12295  teses avaliadas e  558  teses relacionadas a O&G encontradas.
# 12296  teses avaliadas e  559  teses relacionadas a O&G encontradas.
# 12297  teses avaliadas e  560  teses relacionadas a O&G encontradas.
# 12298  teses avaliadas e  561  teses relacionadas a O&G encontradas.
# 12302  teses avaliadas e  562  teses relacionadas a O&G encontradas.
# 12303  teses avaliadas e  563  teses relacionadas a O&G encontradas.
# 12304  teses avaliadas e  564  teses relacionadas a O&G encontradas.
# 12305  teses avaliadas e  565  teses relacionadas a O&G encontradas.
# 12306  teses avaliadas e  566  teses relacionadas a O&G encontradas.
# 12307  teses avaliadas e  567  teses relacionadas a O&G encontradas.
# 12308  teses avaliadas e  568  teses relacionadas a O&G encontradas.
# 12310  teses avaliadas e  569  teses relacionadas a O&G encontradas.
# 12311  teses avaliadas e  570  teses relacionadas a O&G encontradas.
# 12312  teses avaliadas e  571  teses relacionadas a O&G encontradas.
# 12313  teses avaliadas e  572  teses relacionadas a O&G encontradas.
# 12314  teses avaliadas e  573  teses relacionadas a O&G encontradas.
# 12315  teses avaliadas e  574  teses relacionadas a O&G encontradas.
# 12316  teses avaliadas e  575  teses relacionadas a O&G encontradas.
# 12317  teses avaliadas e  576  teses relacionadas a O&G encontradas.
# 12318  teses avaliadas e  577  teses relacionadas a O&G encontradas.
# 12319  teses avaliadas e  578  teses relacionadas a O&G encontradas.
# 12323  teses avaliadas e  579  teses relacionadas a O&G encontradas.
# 12326  teses avaliadas e  580  teses relacionadas a O&G encontradas.
# 12328  teses avaliadas e  581  teses relacionadas a O&G encontradas.
# 12329  teses avaliadas e  582  teses relacionadas a O&G encontradas.
# 12330  teses avaliadas e  583  teses relacionadas a O&G encontradas.
# 12333  teses avaliadas e  584  teses relacionadas a O&G encontradas.
# 12334  teses avaliadas e  585  teses relacionadas a O&G encontradas.
# 12335  teses avaliadas e  586  teses relacionadas a O&G encontradas.
# 12336  teses avaliadas e  587  teses relacionadas a O&G encontradas.
# 12340  teses avaliadas e  588  teses relacionadas a O&G encontradas.
# 12343  teses avaliadas e  589  teses relacionadas a O&G encontradas.
# 12344  teses avaliadas e  590  teses relacionadas a O&G encontradas.
# 12346  teses avaliadas e  591  teses relacionadas a O&G encontradas.
# 12347  teses avaliadas e  592  teses relacionadas a O&G encontradas.
# 12348  teses avaliadas e  593  teses relacionadas a O&G encontradas.
# 12349  teses avaliadas e  594  teses relacionadas a O&G encontradas.
# 12351  teses avaliadas e  595  teses relacionadas a O&G encontradas.
# 12352  teses avaliadas e  596  teses relacionadas a O&G encontradas.
# 12353  teses avaliadas e  597  teses relacionadas a O&G encontradas.
# 12354  teses avaliadas e  598  teses relacionadas a O&G encontradas.
# 12355  teses avaliadas e  599  teses relacionadas a O&G encontradas.
# 12356  teses avaliadas e  600  teses relacionadas a O&G encontradas.
# 12358  teses avaliadas e  601  teses relacionadas a O&G encontradas.
# 12359  teses avaliadas e  602  teses relacionadas a O&G encontradas.
# 12360  teses avaliadas e  603  teses relacionadas a O&G encontradas.
# 12361  teses avaliadas e  604  teses relacionadas a O&G encontradas.
# 12364  teses avaliadas e  605  teses relacionadas a O&G encontradas.
# 12365  teses avaliadas e  606  teses relacionadas a O&G encontradas.
# 12366  teses avaliadas e  607  teses relacionadas a O&G encontradas.
# 12367  teses avaliadas e  608  teses relacionadas a O&G encontradas.
# 12368  teses avaliadas e  609  teses relacionadas a O&G encontradas.
# 12369  teses avaliadas e  610  teses relacionadas a O&G encontradas.
# 12371  teses avaliadas e  611  teses relacionadas a O&G encontradas.
# 12374  teses avaliadas e  612  teses relacionadas a O&G encontradas.
# 12375  teses avaliadas e  613  teses relacionadas a O&G encontradas.
# 12377  teses avaliadas e  614  teses relacionadas a O&G encontradas.
# 12379  teses avaliadas e  615  teses relacionadas a O&G encontradas.
# 12380  teses avaliadas e  616  teses relacionadas a O&G encontradas.
# 12381  teses avaliadas e  617  teses relacionadas a O&G encontradas.
# 12384  teses avaliadas e  618  teses relacionadas a O&G encontradas.
# 12385  teses avaliadas e  619  teses relacionadas a O&G encontradas.
# 12386  teses avaliadas e  620  teses relacionadas a O&G encontradas.
# 12387  teses avaliadas e  621  teses relacionadas a O&G encontradas.
# 12388  teses avaliadas e  622  teses relacionadas a O&G encontradas.
# 12389  teses avaliadas e  623  teses relacionadas a O&G encontradas.
# 12390  teses avaliadas e  624  teses relacionadas a O&G encontradas.
# 12391  teses avaliadas e  625  teses relacionadas a O&G encontradas.
# 12395  teses avaliadas e  626  teses relacionadas a O&G encontradas.
# 12396  teses avaliadas e  627  teses relacionadas a O&G encontradas.
# 12397  teses avaliadas e  628  teses relacionadas a O&G encontradas.
# 12399  teses avaliadas e  629  teses relacionadas a O&G encontradas.
# 12400  teses avaliadas e  630  teses relacionadas a O&G encontradas.
# 12401  teses avaliadas e  631  teses relacionadas a O&G encontradas.
# 12404  teses avaliadas e  632  teses relacionadas a O&G encontradas.
# 12405  teses avaliadas e  633  teses relacionadas a O&G encontradas.
# 12407  teses avaliadas e  634  teses relacionadas a O&G encontradas.
# 12409  teses avaliadas e  635  teses relacionadas a O&G encontradas.
# 12411  teses avaliadas e  636  teses relacionadas a O&G encontradas.
# 12412  teses avaliadas e  637  teses relacionadas a O&G encontradas.
# 12413  teses avaliadas e  638  teses relacionadas a O&G encontradas.
# 12414  teses avaliadas e  639  teses relacionadas a O&G encontradas.
# 12415  teses avaliadas e  640  teses relacionadas a O&G encontradas.
# 12416  teses avaliadas e  641  teses relacionadas a O&G encontradas.
# 12509  teses avaliadas e  642  teses relacionadas a O&G encontradas.
# 12520  teses avaliadas e  643  teses relacionadas a O&G encontradas.
# 12524  teses avaliadas e  644  teses relacionadas a O&G encontradas.
# 12530  teses avaliadas e  645  teses relacionadas a O&G encontradas.
# 12536  teses avaliadas e  646  teses relacionadas a O&G encontradas.
# 12553  teses avaliadas e  647  teses relacionadas a O&G encontradas.
# 12574  teses avaliadas e  648  teses relacionadas a O&G encontradas.
# 12575  teses avaliadas e  649  teses relacionadas a O&G encontradas.
# 12579  teses avaliadas e  650  teses relacionadas a O&G encontradas.
# 12582  teses avaliadas e  651  teses relacionadas a O&G encontradas.
# 12587  teses avaliadas e  652  teses relacionadas a O&G encontradas.
# 12589  teses avaliadas e  653  teses relacionadas a O&G encontradas.
# 12595  teses avaliadas e  654  teses relacionadas a O&G encontradas.
# 12596  teses avaliadas e  655  teses relacionadas a O&G encontradas.
# 12598  teses avaliadas e  656  teses relacionadas a O&G encontradas.
# 12600  teses avaliadas e  657  teses relacionadas a O&G encontradas.
# 12601  teses avaliadas e  658  teses relacionadas a O&G encontradas.
# 12603  teses avaliadas e  659  teses relacionadas a O&G encontradas.
# 12604  teses avaliadas e  660  teses relacionadas a O&G encontradas.
# 12607  teses avaliadas e  661  teses relacionadas a O&G encontradas.
# 12609  teses avaliadas e  662  teses relacionadas a O&G encontradas.
# 12612  teses avaliadas e  663  teses relacionadas a O&G encontradas.
# 12613  teses avaliadas e  664  teses relacionadas a O&G encontradas.
# 12614  teses avaliadas e  665  teses relacionadas a O&G encontradas.
# 12616  teses avaliadas e  666  teses relacionadas a O&G encontradas.
# 12617  teses avaliadas e  667  teses relacionadas a O&G encontradas.
# 12618  teses avaliadas e  668  teses relacionadas a O&G encontradas.
# 12619  teses avaliadas e  669  teses relacionadas a O&G encontradas.
# 12620  teses avaliadas e  670  teses relacionadas a O&G encontradas.
# 12621  teses avaliadas e  671  teses relacionadas a O&G encontradas.
# 12624  teses avaliadas e  672  teses relacionadas a O&G encontradas.
# 12625  teses avaliadas e  673  teses relacionadas a O&G encontradas.

# %%
# Incluindo um ID para cada tese
universidade = 'UFRN'
metadados_ufrn['PDF_ID'] = metadados_ufrn['Download Texto Completo:'].apply(lambda x: universidade + 
                                                                            '_' + 
                                                                            re.sub('/', '_', x[-6:]))

# %%
metadados_ufrn.to_json('metadados_ufrn.json', orient = 'index')

# %%
# Carregando arquivos já gravados
metadados_ufrn = pd.read_json('metadados_ufrn.json', orient = 'index')

# %% [markdown]
# A próxima etapa será fazer o download das teses classificadas como relevante para o domínio de O&G

# %%
for tese in metadados_ufrn.iterrows():
    print(tese[1]['PDF_ID'])
    try:
        #preparar a url
        url = tese[1]['Download Texto Completo:']

        #Fazer requisição e parsear o arquivo html
        f = requests.get(url, proxies = proxies).text 
        soup = bs(f, "html.parser")

        #Coletando link para arquivo das teses
        links = []
        for doc in soup.find_all('a', href=True):
            if doc.get_text() == 'View/Open':
                links.append(doc['href'])

        #Recuperando e gravando arquivo PDF
        url = 'http://repositorio.ufrn.br' + links[0]
        pdf = requests.get(url, proxies = proxies)
        filename = tese[1]['PDF_ID'] + '.pdf'
        with open(filename, 'wb') as f:
            f.write(pdf.content)
    except:
        pass
# Out:
# UFRN__19271
# UFRN__19291
# UFRN__19293
# UFRN__19370
# UFRN__19380
# UFRN__19393
# UFRN__19398
# UFRN__19421
# UFRN__19424
# UFRN__19428
# UFRN__19443
# UFRN__19500
# UFRN__19536
# UFRN__19557
# UFRN__19621
# UFRN__19652
# UFRN__19670
# UFRN__19675
# UFRN__19690
# UFRN__19734
# UFRN__19778
# UFRN__19828
# UFRN__19834
# UFRN__19837
# UFRN__19840
# UFRN__19852
# UFRN__19897
# UFRN__19900
# UFRN__19938
# UFRN__19939
# UFRN__19994
# UFRN__20014
# UFRN__20022
# UFRN__20026
# UFRN__20027
# UFRN__20033
# UFRN__20056
# UFRN__20106
# UFRN__20146
# UFRN__20162
# UFRN__20182
# UFRN__20186
# UFRN__20222
# UFRN__20295
# UFRN__20337
# UFRN__20379
# UFRN__20394
# UFRN__20403
# UFRN__20414
# UFRN__20434
# UFRN__20437
# UFRN__20477
# UFRN__20491
# UFRN__20550
# UFRN__20555
# UFRN__20560
# UFRN__20563
# UFRN__20566
# UFRN__20567
# UFRN__20598
# UFRN__20604
# UFRN__20605
# UFRN__20624
# UFRN__20631
# UFRN__20693
# UFRN__20711
# UFRN__20773
# UFRN__20779
# UFRN__20909
# UFRN__20933
# UFRN__20935
# UFRN__20944
# UFRN__20966
# UFRN__21036
# UFRN__21045
# UFRN__21046
# UFRN__21047
# UFRN__21053
# UFRN__21136
# UFRN__21178
# UFRN__21184
# UFRN__21230
# UFRN__21231
# UFRN__21333
# UFRN__21334
# UFRN__12073
# UFRN__12078
# UFRN__12101
# UFRN__12122
# UFRN__12420
# UFRN__12483
# UFRN__12608
# UFRN__12655
# UFRN__12658
# UFRN__12683
# UFRN__12684
# UFRN__12691
# UFRN__12692
# UFRN__12695
# UFRN__12699
# UFRN__12703
# UFRN__12707
# UFRN__12708
# UFRN__12720
# UFRN__12724
# UFRN__12728
# UFRN__12729
# UFRN__12736
# UFRN__12742
# UFRN__12751
# UFRN__12755
# UFRN__12765
# UFRN__12766
# UFRN__12771
# UFRN__12786
# UFRN__12790
# UFRN__12791
# UFRN__12801
# UFRN__12802
# UFRN__12803
# UFRN__12815
# UFRN__12817
# UFRN__12838
# UFRN__12855
# UFRN__12858
# UFRN__12861
# UFRN__12862
# UFRN__12870
# UFRN__12879
# UFRN__12880
# UFRN__12881
# UFRN__12882
# UFRN__12886
# UFRN__12887
# UFRN__12888
# UFRN__12889
# UFRN__12890
# UFRN__12891
# UFRN__12892
# UFRN__12894
# UFRN__12895
# UFRN__12896
# UFRN__12897
# UFRN__12898
# UFRN__12899
# UFRN__12900
# UFRN__12901
# UFRN__12902
# UFRN__12903
# UFRN__12907
# UFRN__12910
# UFRN__12912
# UFRN__12913
# UFRN__12914
# UFRN__12917
# UFRN__12918
# UFRN__12919
# UFRN__12920
# UFRN__12924
# UFRN__12927
# UFRN__12928
# UFRN__12930
# UFRN__12931
# UFRN__12932
# UFRN__12933
# UFRN__12935
# UFRN__12936
# UFRN__12937
# UFRN__12938
# UFRN__12939
# UFRN__12940
# UFRN__12942
# UFRN__12943
# UFRN__12944
# UFRN__12945
# UFRN__12948
# UFRN__12949
# UFRN__12950
# UFRN__12951
# UFRN__12952
# UFRN__12953
# UFRN__12955
# UFRN__12958
# UFRN__12959
# UFRN__12961
# UFRN__12963
# UFRN__12964
# UFRN__12965
# UFRN__12968
# UFRN__12969
# UFRN__12970
# UFRN__12971
# UFRN__12972
# UFRN__12973
# UFRN__12974
# UFRN__12975
# UFRN__12979
# UFRN__12980
# UFRN__12981
# UFRN__12983
# UFRN__12984
# UFRN__12985
# UFRN__12988
# UFRN__12989
# UFRN__12991
# UFRN__12993
# UFRN__12995
# UFRN__12996
# UFRN__12997
# UFRN__12998
# UFRN__12999
# UFRN__13000
# UFRN__13001
# UFRN__13002
# UFRN__13004
# UFRN__13006
# UFRN__13007
# UFRN__13009
# UFRN__13010
# UFRN__13013
# UFRN__13015
# UFRN__13018
# UFRN__13019
# UFRN__13020
# UFRN__13022
# UFRN__13023
# UFRN__13024
# UFRN__13025
# UFRN__13026
# UFRN__13027
# UFRN__13030
# UFRN__13031
# UFRN__13033
# UFRN__13035
# UFRN__13037
# UFRN__13038
# UFRN__13068
# UFRN__13080
# UFRN__13838
# UFRN__13881
# UFRN__13884
# UFRN__13890
# UFRN__13897
# UFRN__13903
# UFRN__13905
# UFRN__13907
# UFRN__13909
# UFRN__13910
# UFRN__13911
# UFRN__13916
# UFRN__13935
# UFRN__13948
# UFRN__13965
# UFRN__14007
# UFRN__14058
# UFRN__14059
# UFRN__14067
# UFRN__14073
# UFRN__14094
# UFRN__14865
# UFRN__14874
# UFRN__14900
# UFRN__14905
# UFRN__14947
# UFRN__14980
# UFRN__15022
# UFRN__15027
# UFRN__15098
# UFRN__15100
# UFRN__15116
# UFRN__15154
# UFRN__15157
# UFRN__15159
# UFRN__15165
# UFRN__15199
# UFRN__15229
# UFRN__15251
# UFRN__15256
# UFRN__15257
# UFRN__15283
# UFRN__15291
# UFRN__15292
# UFRN__15296
# UFRN__15297
# UFRN__15304
# UFRN__15309
# UFRN__15346
# UFRN__15359
# UFRN__15361
# UFRN__15384
# UFRN__15385
# UFRN__15400
# UFRN__15424
# UFRN__15430
# UFRN__15444
# UFRN__15459
# UFRN__15460
# UFRN__15465
# UFRN__15470
# UFRN__15489
# UFRN__15494
# UFRN__15495
# UFRN__15512
# UFRN__15518
# UFRN__15521
# UFRN__15546
# UFRN__15550
# UFRN__15558
# UFRN__15572
# UFRN__15579
# UFRN__15585
# UFRN__15589
# UFRN__15591
# UFRN__15602
# UFRN__15618
# UFRN__15629
# UFRN__15633
# UFRN__15639
# UFRN__15645
# UFRN__15662
# UFRN__15683
# UFRN__15684
# UFRN__15688
# UFRN__15691
# UFRN__15696
# UFRN__15698
# UFRN__15720
# UFRN__15721
# UFRN__15722
# UFRN__15730
# UFRN__15732
# UFRN__15737
# UFRN__15740
# UFRN__15743
# UFRN__15744
# UFRN__15746
# UFRN__15747
# UFRN__15750
# UFRN__15751
# UFRN__15755
# UFRN__15756
# UFRN__15762
# UFRN__15765
# UFRN__15766
# UFRN__15768
# UFRN__15773
# UFRN__15774
# UFRN__15775
# UFRN__15781
# UFRN__15782
# UFRN__15783
# UFRN__15784
# UFRN__15788
# UFRN__15798
# UFRN__15799
# UFRN__15801
# UFRN__15805
# UFRN__15808
# UFRN__15811
# UFRN__15819
# UFRN__15820
# UFRN__15823
# UFRN__15825
# UFRN__15830
# UFRN__15837
# UFRN__15844
# UFRN__15846
# UFRN__15850
# UFRN__15856
# UFRN__15861
# UFRN__15864
# UFRN__15865
# UFRN__15867
# UFRN__15871
# UFRN__15872
# UFRN__15877
# UFRN__15878
# UFRN__15880
# UFRN__15884
# UFRN__15887
# UFRN__15888
# UFRN__15889
# UFRN__15893
# UFRN__15895
# UFRN__15902
# UFRN__15905
# UFRN__15909
# UFRN__15911
# UFRN__15913
# UFRN__15914
# UFRN__15915
# UFRN__15916
# UFRN__15918
# UFRN__15919
# UFRN__15921
# UFRN__15924
# UFRN__15925
# UFRN__15926
# UFRN__15927
# UFRN__15929
# UFRN__15933
# UFRN__15939
# UFRN__15950
# UFRN__16010
# UFRN__16531
# UFRN__16533
# UFRN__16545
# UFRN__16933
# UFRN__17007
# UFRN__17014
# UFRN__17593
# UFRN__17603
# UFRN__17609
# UFRN__17613
# UFRN__17614
# UFRN__17616
# UFRN__17619
# UFRN__17620
# UFRN__17621
# UFRN__17623
# UFRN__17629
# UFRN__17631
# UFRN__17638
# UFRN__17640
# UFRN__17648
# UFRN__17661
# UFRN__17667
# UFRN__17681
# UFRN__17685
# UFRN__17687
# UFRN__17698
# UFRN__17699
# UFRN__17707
# UFRN__17709
# UFRN__17710
# UFRN__17719
# UFRN__17728
# UFRN__17730
# UFRN__17743
# UFRN__17762
# UFRN__17764
# UFRN__17765
# UFRN__17772
# UFRN__17774
# UFRN__17775
# UFRN__17780
# UFRN__17781
# UFRN__17783
# UFRN__17786
# UFRN__17789
# UFRN__17793
# UFRN__17794
# UFRN__17797
# UFRN__17798
# UFRN__17799
# UFRN__17801
# UFRN__17944
# UFRN__17959
# UFRN__17996
# UFRN__18007
# UFRN__18041
# UFRN__18053
# UFRN__18054
# UFRN__18061
# UFRN__18092
# UFRN__18118
# UFRN__18308
# UFRN__18342
# UFRN__18343
# UFRN__18346
# UFRN__18349
# UFRN__18353
# UFRN__18360
# UFRN__18365
# UFRN__18534
# UFRN__18535
# UFRN__18536
# UFRN__18560
# UFRN__18561
# UFRN__18571
# UFRN__18576
# UFRN__18635
# UFRN__18679
# UFRN__18681
# UFRN__18734
# UFRN__18742
# UFRN__18743
# UFRN__18754
# UFRN__18755
# UFRN__18767
# UFRN__18771
# UFRN__18776
# UFRN__18778
# UFRN__18779
# UFRN__18780
# UFRN__18783
# UFRN__18786
# UFRN__18790
# UFRN__18791
# UFRN__18796
# UFRN__18798
# UFRN__18801
# UFRN__18805
# UFRN__18811
# UFRN__18816
# UFRN__18821
# UFRN__18827
# UFRN__18828
# UFRN__18829
# UFRN__18833
# UFRN__18836
# UFRN__18837
# UFRN__18841
# UFRN__18842
# UFRN__18843
# UFRN__18844
# UFRN__18882
# UFRN__18939
# UFRN__18966
# UFRN__21423
# UFRN__21425
# UFRN__21437
# UFRN__21478
# UFRN__21541
# UFRN__21546
# UFRN__21564
# UFRN__21609
# UFRN__21671
# UFRN__21676
# UFRN__21723
# UFRN__21792
# UFRN__21813
# UFRN__21836
# UFRN__21857
# UFRN__21872
# UFRN__21875
# UFRN__21884
# UFRN__21910
# UFRN__21922
# UFRN__21941
# UFRN__21942
# UFRN__21946
# UFRN__21956
# UFRN__21958
# UFRN__21979
# UFRN__21980
# UFRN__21999
# UFRN__22005
# UFRN__22043
# UFRN__22075
# UFRN__22094
# UFRN__22096
# UFRN__22131
# UFRN__22209
# UFRN__22215
# UFRN__22239
# UFRN__22256
# UFRN__22339
# UFRN__22340
# UFRN__22372
# UFRN__22374
# UFRN__22385
# UFRN__22403
# UFRN__22444
# UFRN__22445
# UFRN__22469
# UFRN__22518
# UFRN__22554
# UFRN__22560
# UFRN__22567
# UFRN__22576
# UFRN__22737
# UFRN__22741
# UFRN__22810
# UFRN__23362
# UFRN__23389
# UFRN__23397
# UFRN__23517
# UFRN__23536
# UFRN__23543
# UFRN__23658
# UFRN__23683
# UFRN__23685
# UFRN__23698
# UFRN__23713
# UFRN__23717
# UFRN__23758
# UFRN__23835
# UFRN__23875
# UFRN__23877
# UFRN__23878
# UFRN__23879
# UFRN__24006
# UFRN__24031
# UFRN__24048
# UFRN__24149
# UFRN__24150
# UFRN__24151
# UFRN__24234
# UFRN__24272
# UFRN__24273
# UFRN__24283
# UFRN__24284
# UFRN__24290
# UFRN__24418
# UFRN__24464
# UFRN__24465
# UFRN__24490
# UFRN__24504
# UFRN__24516
# UFRN__24642
# UFRN__24659
# UFRN__24674
# UFRN__24675
# UFRN__24787
# UFRN__24796
# UFRN__24826
# UFRN__24862
# UFRN__24939
# UFRN__25076
# UFRN__25108
# UFRN__25112
# UFRN__25120
# UFRN__25121
# UFRN__25159
# UFRN__25227
# UFRN__25240
# UFRN__25242
# UFRN__25290
# UFRN__25448
# UFRN__25495
# UFRN__25498
# UFRN__25570
# UFRN__25659
# UFRN__25669
# UFRN__25671
# UFRN__25696
# UFRN__25706
# UFRN__25733
# UFRN__25790
# UFRN__25808
# UFRN__25825
# UFRN__25909
# UFRN__25945
# UFRN__25947
# UFRN__25964
# UFRN__25971
# UFRN__25993
# UFRN__26013
# UFRN__26063
# UFRN__26211
# UFRN__26252
# UFRN__26274
# UFRN__26314
# UFRN__26315
# UFRN__26410
# UFRN__26509
# UFRN__26545
# UFRN__26627
# UFRN__26634
# UFRN__26647
# UFRN__26676
# UFRN__26682
# UFRN__26683
# UFRN__26775
# UFRN__26776
# UFRN__26777
# UFRN__26930
# UFRN__26934
# UFRN__26946
# UFRN__26947
# UFRN__27013
# UFRN__27014
