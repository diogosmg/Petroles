# %% [markdown]
# Script para buscar resumos das teses elaboradas pelos empregados da Petrobras

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import json
import nltk
from nltk.tokenize import word_tokenize
from langdetect import detect
from langdetect import detect_langs
from keras.models import load_model
import gensim
from gensim.models import Word2Vec
import csv
# Out:
# Using TensorFlow backend.
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# Definindo configurações globais de proxy para realizar a extração dentro da rede Petrobras
chave = 'upe2'
pwd = 'fBO61290'
proxy_url = 'http://'+chave+':'+pwd+'@inet-sys.gnet.petrobras.com.br:804/'
proxies = {
  'http' : proxy_url ,
  'https' : proxy_url ,
}

# %% [markdown]
# Inicialmente entraremos no site da BDTD e buscaremos os links de todas as teses de uma determinada intituição.

# %%
#função para coletar os links das tese

def get_links(page):
        
    #preparar a url
    url = ('http://bdtd.ibict.br/vufind/Search/Results?filter%5B%5D=institution%3A%22UNICAMP%22&type=AllFields&page=' +
           str(page))
    
    #Fazer requisição e parsear o arquivo html
    f = requests.get(url).text #, proxies = proxies).text 
    soup = bs(f, "html.parser")

    #Coletando link para as teses
    links = []
    for doc in soup.find_all('a', href=True):
        if 'title' in doc.get('class', []):
            links.append(doc['href'])
    return links

# %%
#Coletar o link de todas as teses
start_page = 2000
n_pages = 2285 # Cada página retorna 20 teses

links = []

for p in range(start_page, n_pages):
    link = get_links(p)
    if link != []:
        links = links + link
    else:
        break
    
    if p % 100 == 0:
        print (p*20, ' links capturados, ', p, ' páginas')
        with open('links_unicamp', "w") as output:
            writer = csv.writer(output, lineterminator='\n')
            for val in links:
                writer.writerow([val])
                
with open('links_unicamp', "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in links:
        writer.writerow([val]) 
print (p*20, ' links capturados, ', p, ' páginas')
# Out:
# 40000  links capturados,  2000  páginas
# 42000  links capturados,  2100  páginas
# 44000  links capturados,  2200  páginas
# 45680  links capturados,  2284  páginas

# %%
# Abrindo arquivo gravado anteriormente

#links = []
#with open('links_unicamp', 'r') as f:
#    reader = csv.reader(f)
#    for link in reader:
#        links.append(link[0])

# %% [markdown]
# Em seguida vamos recuperar os metadados de cada link coletado anteriormente.

# %%
#função para buscar os metadados das teses no BDTD
def tese_link(link):
    #definir url
    url = 'http://bdtd.ibict.br' + link
    
    #Requisitar html e fazer o parser
    f = requests.get(url).text #, proxies = proxies).text 
    soup = bs(f, "html.parser")

    #Dicionário para armazenar as informações da tese
    tese = {}  
    
    #Adicionar título
    tese['Title'] = soup.find('h3').get_text()
    for doc in soup.find_all('tr'):
        #Identificar atributo
        try:
            atributo = doc.find('th').get_text()
        except:
            pass
        #Verificar se o atributo possui mais de um dado
        for row in doc.find_all('td'):
            #Adicionar o atributo no dicionário
            if row.find('div') == None:
                try:
                    tese[atributo] = doc.find('td').get_text()
                except:
                    pass
            else:
                element = []
                #No dicionário, adicionar todos os dados ao seu respectivo atributo
                for e in doc.find_all('div'):
                    try:
                        sub_e = []
                        for sub_element in e.find_all('a'):
                            element.append(sub_element.get_text()) 
                        #element.append(sub_e)
                    except:
                        pass
                tese[atributo] = element
    
    return(tese)

# %% [markdown]
# Como em alguns casos o resumo português e inglês se misturaram, foi implementado uma função para separar os textos misturados

# %%
# Função para separar resumos português e inglês
def separacao_port_engl(abstract):

    mix_sent = nltk.sent_tokenize(abstract)

    new_mix = []
    for sent in mix_sent:
        position = sent.find('.')
        if position != len(sent)-1:
            sent_1 = sent[:position+1]
            sent_2 = sent[position+1:]
            new_mix.append(sent_1)
            new_mix.append(sent_2)
        else:
            new_mix.append(sent)

    mix_sent = new_mix

    port = []
    engl = []

    for sent in mix_sent:
        try:
            if detect (sent) == 'pt':
                port.append(sent)
            else:
                engl.append (sent)
        except:
            pass

    port = " ".join(port)
    engl = " ".join(engl)

    return(port, engl)

# %% [markdown]
# Até esse momento estamos recuperando as informações de todas as teses de uma determinada instituição. No entanto o objetivo é gravar os metadados e salvar o arquivo apenas das teses relacionadas a O&G. Portanto, vamos carregar os algoritmos de classificação e de vetorização de palavras treinados previamente.

# %%
# Carregando modelo Word2Vec
BDTD_word2vec_50 = Word2Vec.load("..\..\..\Embeddings\BDTD_word2vec_50")
# Carregando modelo keras
model_keras = load_model('..\..\..\model_cnn.h5')
model_keras.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 400, 50)           9289150
# _________________________________________________________________
# spatial_dropout1d_6 (Spatial (None, 400, 50)           0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 396, 128)          32128
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 198, 128)          0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 198, 128)          0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 194, 128)          82048
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 97, 128)           0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 97, 128)           0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 93, 128)           82048
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 128)               0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               66048
# _________________________________________________________________
# dense_31 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 9,814,591
# Trainable params: 525,441
# Non-trainable params: 9,289,150
# _________________________________________________________________

# %%
# dicionário proveniente do modelo de word embedding para converter palavras em índices
word2index = {}
for index, word in enumerate(BDTD_word2vec_50.wv.index2word):
    word2index[word] = index
    
# Função para converter texto em sequência de índices
def index_pad_text(text, maxlen, word2index):
    maxlen = 400
    new_text = [] 
    
    for word in word_tokenize(text):
        try:
            new_text.append(word2index[word])
        except:
            pass
    # Add the padding for each sentence. Here I am padding with 0
    if len(new_text) > maxlen:
        new_text = new_text[:400]
    else:
        new_text += [0] * (maxlen - len(new_text))

    return np.array(new_text)

maxlen = 400

# %% [markdown]
# Para cada link coletado será fita as seguintes tarefas:
# * verificar se o texto português e inglês estão misturados;
# * transformar o texto em sequência de índices;
# * classificar quanto a relevância ao domínio de O&G;
# * se for relevante, gravar os metadados

# %%
# Dicionário para agrupar os metadados
metadados = {}
# Contadores te links testados e classificados como O&G
n_test = 0
n_pet = 0
# Testando cada link de links
for link in links:
    n_test += 1
    try:
        # Recuperar o metadados de uma tese
        metadado = tese_link(link)
        # Verificar se existe resumo em inglês, separar texto português/inglês e realocar 
        # os textos separados nas respectivas colunas
        if 'Resumo inglês:' not in metadado:
            metadado['Resumo inglês:'] = separacao_port_engl(metadado['Resumo Português:'])[1]
        metadado['Resumo Português:'] = separacao_port_engl(metadado['Resumo Português:'])[0]
        # Colocando o texto em minúscula
        text = metadado['Resumo Português:'].lower()
        # Convertendo as palavras em sequencias de acordo com o modelo word2vec
        text_seq = index_pad_text(text, maxlen, word2index)
        text_seq = text_seq.reshape((1, 400))
        # Usando o algoritmo classificador para prever se a tese é relevante
        pred = model_keras.predict(text_seq)[0]
        #Se a classificação for menor do que 0.2 manter os metadados
        if (pred < 0.2 and len(text) > 100):
            metadado['Classificador'] = pred[0]
            texto_completo = metadado['Download Texto Completo:']
            metadados[texto_completo] = metadado
            n_pet += 1
            # Gravando os resultados em JSON
            metadados_unicamp = pd.DataFrame.from_dict(metadados, orient='index')
            metadados_unicamp.to_json('metadados_unicamp.json', orient = 'index')
            print(n_test, " teses avaliadas e ", n_pet, " teses relacionadas a O&G encontradas.")
    
    except:
        pass
# Out:
# 49  teses avaliadas e  1  teses relacionadas a O&G encontradas.
# 50  teses avaliadas e  2  teses relacionadas a O&G encontradas.
# 51  teses avaliadas e  3  teses relacionadas a O&G encontradas.
# 150  teses avaliadas e  5  teses relacionadas a O&G encontradas.
# 184  teses avaliadas e  6  teses relacionadas a O&G encontradas.
# 186  teses avaliadas e  7  teses relacionadas a O&G encontradas.
# 188  teses avaliadas e  8  teses relacionadas a O&G encontradas.
# 190  teses avaliadas e  9  teses relacionadas a O&G encontradas.
# 191  teses avaliadas e  10  teses relacionadas a O&G encontradas.
# 212  teses avaliadas e  11  teses relacionadas a O&G encontradas.
# 217  teses avaliadas e  12  teses relacionadas a O&G encontradas.
# 267  teses avaliadas e  13  teses relacionadas a O&G encontradas.
# 379  teses avaliadas e  14  teses relacionadas a O&G encontradas.
# 496  teses avaliadas e  15  teses relacionadas a O&G encontradas.
# 581  teses avaliadas e  16  teses relacionadas a O&G encontradas.
# 691  teses avaliadas e  17  teses relacionadas a O&G encontradas.
# 702  teses avaliadas e  18  teses relacionadas a O&G encontradas.
# 731  teses avaliadas e  19  teses relacionadas a O&G encontradas.
# 853  teses avaliadas e  20  teses relacionadas a O&G encontradas.
# 906  teses avaliadas e  21  teses relacionadas a O&G encontradas.
# 1071  teses avaliadas e  22  teses relacionadas a O&G encontradas.
# 1177  teses avaliadas e  23  teses relacionadas a O&G encontradas.
# 1181  teses avaliadas e  24  teses relacionadas a O&G encontradas.
# 1235  teses avaliadas e  25  teses relacionadas a O&G encontradas.
# 1255  teses avaliadas e  26  teses relacionadas a O&G encontradas.
# 1318  teses avaliadas e  27  teses relacionadas a O&G encontradas.
# 1370  teses avaliadas e  28  teses relacionadas a O&G encontradas.
# 1371  teses avaliadas e  29  teses relacionadas a O&G encontradas.
# 1374  teses avaliadas e  30  teses relacionadas a O&G encontradas.
# 1377  teses avaliadas e  31  teses relacionadas a O&G encontradas.
# 1401  teses avaliadas e  32  teses relacionadas a O&G encontradas.
# 1404  teses avaliadas e  33  teses relacionadas a O&G encontradas.
# 1500  teses avaliadas e  34  teses relacionadas a O&G encontradas.
# 1502  teses avaliadas e  35  teses relacionadas a O&G encontradas.
# 1517  teses avaliadas e  36  teses relacionadas a O&G encontradas.
# 1522  teses avaliadas e  37  teses relacionadas a O&G encontradas.
# 1567  teses avaliadas e  38  teses relacionadas a O&G encontradas.
# 1633  teses avaliadas e  39  teses relacionadas a O&G encontradas.
# 1635  teses avaliadas e  40  teses relacionadas a O&G encontradas.
# 1645  teses avaliadas e  41  teses relacionadas a O&G encontradas.
# 1661  teses avaliadas e  42  teses relacionadas a O&G encontradas.
# 1664  teses avaliadas e  43  teses relacionadas a O&G encontradas.
# 1674  teses avaliadas e  44  teses relacionadas a O&G encontradas.
# 1689  teses avaliadas e  45  teses relacionadas a O&G encontradas.
# 1705  teses avaliadas e  46  teses relacionadas a O&G encontradas.
# 1706  teses avaliadas e  47  teses relacionadas a O&G encontradas.
# 1714  teses avaliadas e  48  teses relacionadas a O&G encontradas.
# 1715  teses avaliadas e  49  teses relacionadas a O&G encontradas.
# 1723  teses avaliadas e  50  teses relacionadas a O&G encontradas.
# 1728  teses avaliadas e  51  teses relacionadas a O&G encontradas.
# 1735  teses avaliadas e  52  teses relacionadas a O&G encontradas.
# 1754  teses avaliadas e  53  teses relacionadas a O&G encontradas.
# 1853  teses avaliadas e  54  teses relacionadas a O&G encontradas.
# 1856  teses avaliadas e  55  teses relacionadas a O&G encontradas.
# 1864  teses avaliadas e  56  teses relacionadas a O&G encontradas.
# 1986  teses avaliadas e  57  teses relacionadas a O&G encontradas.
# 1995  teses avaliadas e  58  teses relacionadas a O&G encontradas.
# 2019  teses avaliadas e  59  teses relacionadas a O&G encontradas.
# 2051  teses avaliadas e  60  teses relacionadas a O&G encontradas.
# 2114  teses avaliadas e  61  teses relacionadas a O&G encontradas.
# 2567  teses avaliadas e  62  teses relacionadas a O&G encontradas.
# 2572  teses avaliadas e  63  teses relacionadas a O&G encontradas.
# 2580  teses avaliadas e  64  teses relacionadas a O&G encontradas.
# 2792  teses avaliadas e  65  teses relacionadas a O&G encontradas.
# 2828  teses avaliadas e  66  teses relacionadas a O&G encontradas.
# 3060  teses avaliadas e  67  teses relacionadas a O&G encontradas.
# 3067  teses avaliadas e  68  teses relacionadas a O&G encontradas.
# 3087  teses avaliadas e  69  teses relacionadas a O&G encontradas.
# 3187  teses avaliadas e  70  teses relacionadas a O&G encontradas.
# 3322  teses avaliadas e  71  teses relacionadas a O&G encontradas.
# 3327  teses avaliadas e  72  teses relacionadas a O&G encontradas.
# 3393  teses avaliadas e  73  teses relacionadas a O&G encontradas.
# 3403  teses avaliadas e  74  teses relacionadas a O&G encontradas.
# 3476  teses avaliadas e  75  teses relacionadas a O&G encontradas.
# 3484  teses avaliadas e  76  teses relacionadas a O&G encontradas.
# 3529  teses avaliadas e  77  teses relacionadas a O&G encontradas.
# 3600  teses avaliadas e  78  teses relacionadas a O&G encontradas.
# 3689  teses avaliadas e  79  teses relacionadas a O&G encontradas.
# 3738  teses avaliadas e  80  teses relacionadas a O&G encontradas.
# 3752  teses avaliadas e  81  teses relacionadas a O&G encontradas.
# 3845  teses avaliadas e  82  teses relacionadas a O&G encontradas.
# 4044  teses avaliadas e  83  teses relacionadas a O&G encontradas.
# 4064  teses avaliadas e  84  teses relacionadas a O&G encontradas.
# 4080  teses avaliadas e  85  teses relacionadas a O&G encontradas.
# 4092  teses avaliadas e  86  teses relacionadas a O&G encontradas.
# 4126  teses avaliadas e  87  teses relacionadas a O&G encontradas.
# 4197  teses avaliadas e  88  teses relacionadas a O&G encontradas.
# 4198  teses avaliadas e  89  teses relacionadas a O&G encontradas.
# 4201  teses avaliadas e  90  teses relacionadas a O&G encontradas.
# 4225  teses avaliadas e  91  teses relacionadas a O&G encontradas.
# 4233  teses avaliadas e  92  teses relacionadas a O&G encontradas.
# 4235  teses avaliadas e  93  teses relacionadas a O&G encontradas.
# 4239  teses avaliadas e  94  teses relacionadas a O&G encontradas.
# 4245  teses avaliadas e  95  teses relacionadas a O&G encontradas.
# 4265  teses avaliadas e  96  teses relacionadas a O&G encontradas.
# 4283  teses avaliadas e  97  teses relacionadas a O&G encontradas.
# 4314  teses avaliadas e  98  teses relacionadas a O&G encontradas.
# 4330  teses avaliadas e  99  teses relacionadas a O&G encontradas.
# 4612  teses avaliadas e  100  teses relacionadas a O&G encontradas.
# 4614  teses avaliadas e  101  teses relacionadas a O&G encontradas.
# 4880  teses avaliadas e  102  teses relacionadas a O&G encontradas.
# 4882  teses avaliadas e  103  teses relacionadas a O&G encontradas.
# 4883  teses avaliadas e  104  teses relacionadas a O&G encontradas.
# 4935  teses avaliadas e  105  teses relacionadas a O&G encontradas.
# 4952  teses avaliadas e  106  teses relacionadas a O&G encontradas.
# 4977  teses avaliadas e  107  teses relacionadas a O&G encontradas.
# 4978  teses avaliadas e  108  teses relacionadas a O&G encontradas.
# 5042  teses avaliadas e  109  teses relacionadas a O&G encontradas.
# 5197  teses avaliadas e  110  teses relacionadas a O&G encontradas.
# 5350  teses avaliadas e  111  teses relacionadas a O&G encontradas.
# 5393  teses avaliadas e  112  teses relacionadas a O&G encontradas.
# 5421  teses avaliadas e  113  teses relacionadas a O&G encontradas.
# 5658  teses avaliadas e  114  teses relacionadas a O&G encontradas.

# %%
metadados_unicamp.to_json('metadados_unicamp_1-20000.json', orient = 'index')

# %%
# Incluindo um ID para cada tese
universidade = 'UNICAMP'
metadados_unicamp['PDF_ID'] = metadados_unicamp['Download Texto Completo:'].apply(lambda x: universidade + '_' + x[-6:])

# %%
# Carregando arquivos já gravados
metadados_unicamp = pd.read_json('metadados_unicamp_40000-45600.json', orient = 'index')

# %% [markdown]
# A próxima etapa será fazer o download das teses classificadas como relevante para o domínio de O&G

# %%
for tese in metadados_unicamp.iterrows():
    try:
        #preparar a url
        url = tese[1]['Download Texto Completo:']

        #Fazer requisição e parsear o arquivo html
        f = requests.get(url, proxies = proxies).text 
        soup = bs(f, "html.parser")

        #Coletando link para arquivo das teses
        links = []
        for doc in soup.find_all('a', href=True):
            if doc.get_text() == 'View/Open':
                links.append(doc['href'])

        #Recuperando e gravando arquivo PDF
        url = 'http://repositorio.unicamp.br' + links[0]
        pdf = requests.get(url, proxies = proxies)
        filename = tese[1]['PDF_ID'] + '.pdf'
        with open(filename, 'wb') as f:
            f.write(pdf.content)
    except:
        pass
